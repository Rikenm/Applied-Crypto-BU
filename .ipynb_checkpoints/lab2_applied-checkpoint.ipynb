# %%
import re
mostCommonWords = ["the","be","to","of","and","a","in","that","have","I","it","for","not","on","with","he","as","you",
"do","at","this","but","his","by","from","they","we","say","her","she","or","will"," an ","my","one","all","would",
"there","their","what","so","up","out","if","about","who","get","which","go","when","me","make","can","like"," time","no","just",
"him","know","take","person","into","year","your","good","some","could","them","see","other","than","then","now","look","only",
"come","its","over","think","also","back","after","use","two","how","our","homework ","first","well","way","even","new","want",
"becaus","any","these","give","day","most","us "]

# %%
def string_2_hex(my_input):
    numbers = [ord(a) for a in my_input]

    result=""
    for i in numbers:
        if len(format(i,'x'))==1:
            result+="0"+format(i,'0x')    #hex() does  the same thing 
        else:
            result+=format(i,'0x')
   
    
    return(result)

# %%
def hex_2_byte(my_input):
   
    hexs = re.findall('..',my_input)

    result = [int(i, 16) for i in hexs]
    
    
    print(result)

# %%
def hex_2_int(result):
    answer = int(result, 16) 
    return answer

# %%
def hex_2_string(my_input):

    

    hexs = re.findall('..',my_input)

    byte = result = [int(i, 16) for i in hexs]


    numbers = map(int, byte)

    result=""

    for i in numbers:
        result+= chr(i)
    
    return(result)

# %%
hex_2_string('062c3235')
# Out:
# '\x06,25'

# %%
#len(hex_i) = 6
c1XorCw = c1XorCw[:-1]
print(c1XorCw[22:len(hex_i)+22],c1XorCw)
# Out:
# ('', '264e5715061d534d071')

# %%
hex_i=string_2_hex("I")
final = (hex_2_int(c1XorCw[22:len(hex_i)+22])^ hex_2_int(hex_i))
print(hex(final))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-770-ec27d38a9793> in <module>()
#       1 hex_i=string_2_hex("I")
# ----> 2 final = (hex_2_int(c1XorCw[22:len(hex_i)+22])^ hex_2_int(hex_i))
#       3 print(hex(final))
#
# <ipython-input-766-5212da95dc6c> in hex_2_int(result)
#       1 def hex_2_int(result):
# ----> 2     answer = int(result, 16)
#       3     return answer
#       4
#
# ValueError: invalid literal for int() with base 16: ''

# %%
hex_i
# Out:
# '49'

# %%
def run():
    c1 = hex_2_int("57fbbaa76f6513d4b0685e651dc75dfed0a2dca24b9e42bf")
    c2 = hex_2_int("71b5edb269784099b77556201ec142f0d0a6c1ed5e9d55b9")
    c1XorCw = (hex(c1^c2)[2:])[:-1]
    print("len:",len(c1XorCw),c1XorCw,(c1XorCw)[46:])
    word_list=[]
    for i in mostCommonWords:
        for j in range(0,len(c1XorCw),2): 
            hex_i=string_2_hex(i)
            answer = (hex(hex_2_int(c1XorCw[j:len(hex_i)+j]) ^ hex_2_int(hex_i)))
            
            if len(answer[2:])< len((hex_i)) and len(c1XorCw[j:len(hex_i)+j]) == len(hex_i):
                
                answer = "0"*(len((hex_i))-len(answer[2:])) + answer[2:]
                if answer[-1]="L":
                    answer = answer[:-1]
                
    
               
                answer = hex_2_string(answer)
                print(answer,"i:",i,"j:",j)
                print("-------")
                
            elif len(answer[2:]) >= len((hex_i)) and len(c1XorCw[j:len(hex_i)+j]) == len(hex_i): 
                answer = answer
                if answer[-1]="L":
                    answer = answer[:-1]
                    
                
                answer = hex_2_string(answer[2:])
                print(answer,"i:",i,"j:",j)
                print("-------")
                
            if answer.isalpha():
                word_list.append(answer)
                
                
    print(word_list)
# Out:
#   File "<ipython-input-772-906375277a78>", line 15
#     if answer[-1]="L":
#                  ^
# SyntaxError: invalid syntax

# %%
run()
# Out:
# ('len:', 48, '264e5715061d534d071d084503061f0e00041d4f15031706', '06')
# 0x522632
# ('R&2', 'i:', 'the', 'j:', 0)
# -------
# 0x3a3f70
# (':?p', 'i:', 'the', 'j:', 2)
# -------
# 0x237d63
# ('#}c', 'i:', 'the', 'j:', 4)
# -------
# 0x616e78
# ('anx', 'i:', 'the', 'j:', 6)
# -------
# 0x727536
# ('ru6', 'i:', 'the', 'j:', 8)
# -------
# 0x693b28
# ('i;(', 'i:', 'the', 'j:', 10)
# -------
# 0x272562
# ("'%b", 'i:', 'the', 'j:', 12)
# -------
# 0x396f78
# ('9ox', 'i:', 'the', 'j:', 14)
# -------
# 0x73756d
# ('sum', 'i:', 'the', 'j:', 16)
# -------
# 0x696020
# ('i` ', 'i:', 'the', 'j:', 18)
# -------
# 0x7c2d66
# ('|-f', 'i:', 'the', 'j:', 20)
# -------
# 0x316b63
# ('1kc', 'i:', 'the', 'j:', 22)
# -------
# 0x776e7a
# ('wnz', 'i:', 'the', 'j:', 24)
# -------
# 0x72776b
# ('rwk', 'i:', 'the', 'j:', 26)
# -------
# 0x6b6665
# ('kfe', 'i:', 'the', 'j:', 28)
# -------
# 0x7a6861
# ('zha', 'i:', 'the', 'j:', 30)
# -------
# 0x746c78
# ('tlx', 'i:', 'the', 'j:', 32)
# -------
# 0x70752a
# ('pu*', 'i:', 'the', 'j:', 34)
# -------
# 0x692770
# ("i'p", 'i:', 'the', 'j:', 36)
# -------
# 0x3b7d66
# (';}f', 'i:', 'the', 'j:', 38)
# -------
# 0x616b72
# ('akr', 'i:', 'the', 'j:', 40)
# -------
# 0x777f63
# ('w\x7fc', 'i:', 'the', 'j:', 42)
# -------
# 0x442b
# ('D+', 'i:', 'be', 'j:', 0)
# -------
# 0x2c32
# (',2', 'i:', 'be', 'j:', 2)
# -------
# 0x3570
# ('5p', 'i:', 'be', 'j:', 4)
# -------
# 0x7763
# ('wc', 'i:', 'be', 'j:', 6)
# -------
# 0x6478
# ('dx', 'i:', 'be', 'j:', 8)
# -------
# 0x7f36
# ('\x7f6', 'i:', 'be', 'j:', 10)
# -------
# 0x3128
# ('1(', 'i:', 'be', 'j:', 12)
# -------
# 0x2f62
# ('/b', 'i:', 'be', 'j:', 14)
# -------
# 0x6578
# ('ex', 'i:', 'be', 'j:', 16)
# -------
# 0x7f6d
# ('\x7fm', 'i:', 'be', 'j:', 18)
# -------
# 0x6a20
# ('j ', 'i:', 'be', 'j:', 20)
# -------
# 0x2766
# ("'f", 'i:', 'be', 'j:', 22)
# -------
# 0x6163
# ('ac', 'i:', 'be', 'j:', 24)
# -------
# 0x647a
# ('dz', 'i:', 'be', 'j:', 26)
# -------
# 0x7d6b
# ('}k', 'i:', 'be', 'j:', 28)
# -------
# 0x6c65
# ('le', 'i:', 'be', 'j:', 30)
# -------
# 0x6261
# ('ba', 'i:', 'be', 'j:', 32)
# -------
# 0x6678
# ('fx', 'i:', 'be', 'j:', 34)
# -------
# 0x7f2a
# ('\x7f*', 'i:', 'be', 'j:', 36)
# -------
# 0x2d70
# ('-p', 'i:', 'be', 'j:', 38)
# -------
# 0x7766
# ('wf', 'i:', 'be', 'j:', 40)
# -------
# 0x6172
# ('ar', 'i:', 'be', 'j:', 42)
# -------
# 0x7563
# ('uc', 'i:', 'be', 'j:', 44)
# -------
# 0x5221
# ('R!', 'i:', 'to', 'j:', 0)
# -------
# 0x3a38
# (':8', 'i:', 'to', 'j:', 2)
# -------
# 0x237a
# ('#z', 'i:', 'to', 'j:', 4)
# -------
# 0x6169
# ('ai', 'i:', 'to', 'j:', 6)
# -------
# 0x7272
# ('rr', 'i:', 'to', 'j:', 8)
# -------
# 0x693c
# ('i<', 'i:', 'to', 'j:', 10)
# -------
# 0x2722
# ('\'"', 'i:', 'to', 'j:', 12)
# -------
# 0x3968
# ('9h', 'i:', 'to', 'j:', 14)
# -------
# 0x7372
# ('sr', 'i:', 'to', 'j:', 16)
# -------
# 0x6967
# ('ig', 'i:', 'to', 'j:', 18)
# -------
# 0x7c2a
# ('|*', 'i:', 'to', 'j:', 20)
# -------
# 0x316c
# ('1l', 'i:', 'to', 'j:', 22)
# -------
# 0x7769
# ('wi', 'i:', 'to', 'j:', 24)
# -------
# 0x7270
# ('rp', 'i:', 'to', 'j:', 26)
# -------
# 0x6b61
# ('ka', 'i:', 'to', 'j:', 28)
# -------
# 0x7a6f
# ('zo', 'i:', 'to', 'j:', 30)
# -------
# 0x746b
# ('tk', 'i:', 'to', 'j:', 32)
# -------
# 0x7072
# ('pr', 'i:', 'to', 'j:', 34)
# -------
# 0x6920
# ('i ', 'i:', 'to', 'j:', 36)
# -------
# 0x3b7a
# (';z', 'i:', 'to', 'j:', 38)
# -------
# 0x616c
# ('al', 'i:', 'to', 'j:', 40)
# -------
# 0x7778
# ('wx', 'i:', 'to', 'j:', 42)
# -------
# 0x6369
# ('ci', 'i:', 'to', 'j:', 44)
# -------
# 0x4928
# ('I(', 'i:', 'of', 'j:', 0)
# -------
# 0x2131
# ('!1', 'i:', 'of', 'j:', 2)
# -------
# 0x3873
# ('8s', 'i:', 'of', 'j:', 4)
# -------
# 0x7a60
# ('z`', 'i:', 'of', 'j:', 6)
# -------
# 0x697b
# ('i{', 'i:', 'of', 'j:', 8)
# -------
# 0x7235
# ('r5', 'i:', 'of', 'j:', 10)
# -------
# 0x3c2b
# ('<+', 'i:', 'of', 'j:', 12)
# -------
# 0x2261
# ('"a', 'i:', 'of', 'j:', 14)
# -------
# 0x687b
# ('h{', 'i:', 'of', 'j:', 16)
# -------
# 0x726e
# ('rn', 'i:', 'of', 'j:', 18)
# -------
# 0x6723
# ('g#', 'i:', 'of', 'j:', 20)
# -------
# 0x2a65
# ('*e', 'i:', 'of', 'j:', 22)
# -------
# 0x6c60
# ('l`', 'i:', 'of', 'j:', 24)
# -------
# 0x6979
# ('iy', 'i:', 'of', 'j:', 26)
# -------
# 0x7068
# ('ph', 'i:', 'of', 'j:', 28)
# -------
# 0x6166
# ('af', 'i:', 'of', 'j:', 30)
# -------
# 0x6f62
# ('ob', 'i:', 'of', 'j:', 32)
# -------
# 0x6b7b
# ('k{', 'i:', 'of', 'j:', 34)
# -------
# 0x7229
# ('r)', 'i:', 'of', 'j:', 36)
# -------
# 0x2073
# (' s', 'i:', 'of', 'j:', 38)
# -------
# 0x7a65
# ('ze', 'i:', 'of', 'j:', 40)
# -------
# 0x6c71
# ('lq', 'i:', 'of', 'j:', 42)
# -------
# 0x7860
# ('x`', 'i:', 'of', 'j:', 44)
# -------
# 0x472033
# ('G 3', 'i:', 'and', 'j:', 0)
# -------
# 0x2f3971
# ('/9q', 'i:', 'and', 'j:', 2)
# -------
# 0x367b62
# ('6{b', 'i:', 'and', 'j:', 4)
# -------
# 0x746879
# ('thy', 'i:', 'and', 'j:', 6)
# -------
# 0x677337
# ('gs7', 'i:', 'and', 'j:', 8)
# -------
# 0x7c3d29
# ('|=)', 'i:', 'and', 'j:', 10)
# -------
# 0x322363
# ('2#c', 'i:', 'and', 'j:', 12)
# -------
# 0x2c6979
# (',iy', 'i:', 'and', 'j:', 14)
# -------
# 0x66736c
# ('fsl', 'i:', 'and', 'j:', 16)
# -------
# 0x7c6621
# ('|f!', 'i:', 'and', 'j:', 18)
# -------
# 0x692b67
# ('i+g', 'i:', 'and', 'j:', 20)
# -------
# 0x246d62
# ('$mb', 'i:', 'and', 'j:', 22)
# -------
# 0x62687b
# ('bh{', 'i:', 'and', 'j:', 24)
# -------
# 0x67716a
# ('gqj', 'i:', 'and', 'j:', 26)
# -------
# 0x7e6064
# ('~`d', 'i:', 'and', 'j:', 28)
# -------
# 0x6f6e60
# ('on`', 'i:', 'and', 'j:', 30)
# -------
# 0x616a79
# ('ajy', 'i:', 'and', 'j:', 32)
# -------
# 0x65732b
# ('es+', 'i:', 'and', 'j:', 34)
# -------
# 0x7c2171
# ('|!q', 'i:', 'and', 'j:', 36)
# -------
# 0x2e7b67
# ('.{g', 'i:', 'and', 'j:', 38)
# -------
# 0x746d73
# ('tms', 'i:', 'and', 'j:', 40)
# -------
# 0x627962
# ('byb', 'i:', 'and', 'j:', 42)
# -------
# 0x47
# ('G', 'i:', 'a', 'j:', 0)
# -------
# 0x2f
# ('/', 'i:', 'a', 'j:', 2)
# -------
# 0x36
# ('6', 'i:', 'a', 'j:', 4)
# -------
# 0x74
# ('t', 'i:', 'a', 'j:', 6)
# -------
# 0x67
# ('g', 'i:', 'a', 'j:', 8)
# -------
# 0x7c
# ('|', 'i:', 'a', 'j:', 10)
# -------
# 0x32
# ('2', 'i:', 'a', 'j:', 12)
# -------
# 0x2c
# (',', 'i:', 'a', 'j:', 14)
# -------
# 0x66
# ('f', 'i:', 'a', 'j:', 16)
# -------
# 0x7c
# ('|', 'i:', 'a', 'j:', 18)
# -------
# 0x69
# ('i', 'i:', 'a', 'j:', 20)
# -------
# 0x24
# ('$', 'i:', 'a', 'j:', 22)
# -------
# 0x62
# ('b', 'i:', 'a', 'j:', 24)
# -------
# 0x67
# ('g', 'i:', 'a', 'j:', 26)
# -------
# 0x7e
# ('~', 'i:', 'a', 'j:', 28)
# -------
# 0x6f
# ('o', 'i:', 'a', 'j:', 30)
# -------
# 0x61
# ('a', 'i:', 'a', 'j:', 32)
# -------
# 0x65
# ('e', 'i:', 'a', 'j:', 34)
# -------
# 0x7c
# ('|', 'i:', 'a', 'j:', 36)
# -------
# 0x2e
# ('.', 'i:', 'a', 'j:', 38)
# -------
# 0x74
# ('t', 'i:', 'a', 'j:', 40)
# -------
# 0x62
# ('b', 'i:', 'a', 'j:', 42)
# -------
# 0x76
# ('v', 'i:', 'a', 'j:', 44)
# -------
# 0x67
# ('g', 'i:', 'a', 'j:', 46)
# -------
# 0x4f20
# ('O ', 'i:', 'in', 'j:', 0)
# -------
# 0x2739
# ("'9", 'i:', 'in', 'j:', 2)
# -------
# 0x3e7b
# ('>{', 'i:', 'in', 'j:', 4)
# -------
# 0x7c68
# ('|h', 'i:', 'in', 'j:', 6)
# -------
# 0x6f73
# ('os', 'i:', 'in', 'j:', 8)
# -------
# 0x743d
# ('t=', 'i:', 'in', 'j:', 10)
# -------
# 0x3a23
# (':#', 'i:', 'in', 'j:', 12)
# -------
# 0x2469
# ('$i', 'i:', 'in', 'j:', 14)
# -------
# 0x6e73
# ('ns', 'i:', 'in', 'j:', 16)
# -------
# 0x7466
# ('tf', 'i:', 'in', 'j:', 18)
# -------
# 0x612b
# ('a+', 'i:', 'in', 'j:', 20)
# -------
# 0x2c6d
# (',m', 'i:', 'in', 'j:', 22)
# -------
# 0x6a68
# ('jh', 'i:', 'in', 'j:', 24)
# -------
# 0x6f71
# ('oq', 'i:', 'in', 'j:', 26)
# -------
# 0x7660
# ('v`', 'i:', 'in', 'j:', 28)
# -------
# 0x676e
# ('gn', 'i:', 'in', 'j:', 30)
# -------
# 0x696a
# ('ij', 'i:', 'in', 'j:', 32)
# -------
# 0x6d73
# ('ms', 'i:', 'in', 'j:', 34)
# -------
# 0x7421
# ('t!', 'i:', 'in', 'j:', 36)
# -------
# 0x267b
# ('&{', 'i:', 'in', 'j:', 38)
# -------
# 0x7c6d
# ('|m', 'i:', 'in', 'j:', 40)
# -------
# 0x6a79
# ('jy', 'i:', 'in', 'j:', 42)
# -------
# 0x7e68
# ('~h', 'i:', 'in', 'j:', 44)
# -------
# 0x52263661
# ('R&6a', 'i:', 'that', 'j:', 0)
# -------
# 0x3a3f7472
# (':?tr', 'i:', 'that', 'j:', 2)
# -------
# 0x237d6769
# ('#}gi', 'i:', 'that', 'j:', 4)
# -------
# 0x616e7c27
# ("an|'", 'i:', 'that', 'j:', 6)
# -------
# 0x72753239
# ('ru29', 'i:', 'that', 'j:', 8)
# -------
# 0x693b2c73
# ('i;,s', 'i:', 'that', 'j:', 10)
# -------
# 0x27256669
# ("'%fi", 'i:', 'that', 'j:', 12)
# -------
# 0x396f7c7c
# ('9o||', 'i:', 'that', 'j:', 14)
# -------
# 0x73756931
# ('sui1', 'i:', 'that', 'j:', 16)
# -------
# 0x69602477
# ('i`$w', 'i:', 'that', 'j:', 18)
# -------
# 0x7c2d6272
# ('|-br', 'i:', 'that', 'j:', 20)
# -------
# 0x316b676b
# ('1kgk', 'i:', 'that', 'j:', 22)
# -------
# 0x776e7e7a
# ('wn~z', 'i:', 'that', 'j:', 24)
# -------
# 0x72776f74
# ('rwot', 'i:', 'that', 'j:', 26)
# -------
# 0x6b666170
# ('kfap', 'i:', 'that', 'j:', 28)
# -------
# 0x7a686569
# ('zhei', 'i:', 'that', 'j:', 30)
# -------
# 0x746c7c3b
# ('tl|;', 'i:', 'that', 'j:', 32)
# -------
# 0x70752e61
# ('pu.a', 'i:', 'that', 'j:', 34)
# -------
# 0x69277477
# ("i'tw", 'i:', 'that', 'j:', 36)
# -------
# 0x3b7d6263
# (';}bc', 'i:', 'that', 'j:', 38)
# -------
# 0x616b7672
# ('akvr', 'i:', 'that', 'j:', 40)
# -------
# 0x4e2f2170
# ('N/!p', 'i:', 'have', 'j:', 0)
# -------
# 0x26366363
# ('&6cc', 'i:', 'have', 'j:', 2)
# -------
# 0x3f747078
# ('?tpx', 'i:', 'have', 'j:', 4)
# -------
# 0x7d676b36
# ('}gk6', 'i:', 'have', 'j:', 6)
# -------
# 0x6e7c2528
# ('n|%(', 'i:', 'have', 'j:', 8)
# -------
# 0x75323b62
# ('u2;b', 'i:', 'have', 'j:', 10)
# -------
# 0x3b2c7178
# (';,qx', 'i:', 'have', 'j:', 12)
# -------
# 0x25666b6d
# ('%fkm', 'i:', 'have', 'j:', 14)
# -------
# 0x6f7c7e20
# ('o|~ ', 'i:', 'have', 'j:', 16)
# -------
# 0x75693366
# ('ui3f', 'i:', 'have', 'j:', 18)
# -------
# 0x60247563
# ('`$uc', 'i:', 'have', 'j:', 20)
# -------
# 0x2d62707a
# ('-bpz', 'i:', 'have', 'j:', 22)
# -------
# 0x6b67696b
# ('kgik', 'i:', 'have', 'j:', 24)
# -------
# 0x6e7e7865
# ('n~xe', 'i:', 'have', 'j:', 26)
# -------
# 0x776f7661
# ('wova', 'i:', 'have', 'j:', 28)
# -------
# 0x66617278
# ('farx', 'i:', 'have', 'j:', 30)
# -------
# 0x68656b2a
# ('hek*', 'i:', 'have', 'j:', 32)
# -------
# 0x6c7c3970
# ('l|9p', 'i:', 'have', 'j:', 34)
# -------
# 0x752e6366
# ('u.cf', 'i:', 'have', 'j:', 36)
# -------
# 0x27747572
# ("'tur", 'i:', 'have', 'j:', 38)
# -------
# 0x7d626163
# ('}bac', 'i:', 'have', 'j:', 40)
# -------
# 0x6f
# ('o', 'i:', 'I', 'j:', 0)
# -------
# ('\x07', 'i:', 'I', 'j:', 2)
# -------
# 0x1e
# ('\x1e', 'i:', 'I', 'j:', 4)
# -------
# 0x5c
# ('\\', 'i:', 'I', 'j:', 6)
# -------
# 0x4f
# ('O', 'i:', 'I', 'j:', 8)
# -------
# 0x54
# ('T', 'i:', 'I', 'j:', 10)
# -------
# 0x1a
# ('\x1a', 'i:', 'I', 'j:', 12)
# -------
# ('\x04', 'i:', 'I', 'j:', 14)
# -------
# 0x4e
# ('N', 'i:', 'I', 'j:', 16)
# -------
# 0x54
# ('T', 'i:', 'I', 'j:', 18)
# -------
# 0x41
# ('A', 'i:', 'I', 'j:', 20)
# -------
# ('\x0c', 'i:', 'I', 'j:', 22)
# -------
# 0x4a
# ('J', 'i:', 'I', 'j:', 24)
# -------
# 0x4f
# ('O', 'i:', 'I', 'j:', 26)
# -------
# 0x56
# ('V', 'i:', 'I', 'j:', 28)
# -------
# 0x47
# ('G', 'i:', 'I', 'j:', 30)
# -------
# 0x49
# ('I', 'i:', 'I', 'j:', 32)
# -------
# 0x4d
# ('M', 'i:', 'I', 'j:', 34)
# -------
# 0x54
# ('T', 'i:', 'I', 'j:', 36)
# -------
# ('\x06', 'i:', 'I', 'j:', 38)
# -------
# 0x5c
# ('\\', 'i:', 'I', 'j:', 40)
# -------
# 0x4a
# ('J', 'i:', 'I', 'j:', 42)
# -------
# 0x5e
# ('^', 'i:', 'I', 'j:', 44)
# -------
# 0x4f
# ('O', 'i:', 'I', 'j:', 46)
# -------
# 0x4f3a
# ('O:', 'i:', 'it', 'j:', 0)
# -------
# 0x2723
# ("'#", 'i:', 'it', 'j:', 2)
# -------
# 0x3e61
# ('>a', 'i:', 'it', 'j:', 4)
# -------
# 0x7c72
# ('|r', 'i:', 'it', 'j:', 6)
# -------
# 0x6f69
# ('oi', 'i:', 'it', 'j:', 8)
# -------
# 0x7427
# ("t'", 'i:', 'it', 'j:', 10)
# -------
# 0x3a39
# (':9', 'i:', 'it', 'j:', 12)
# -------
# 0x2473
# ('$s', 'i:', 'it', 'j:', 14)
# -------
# 0x6e69
# ('ni', 'i:', 'it', 'j:', 16)
# -------
# 0x747c
# ('t|', 'i:', 'it', 'j:', 18)
# -------
# 0x6131
# ('a1', 'i:', 'it', 'j:', 20)
# -------
# 0x2c77
# (',w', 'i:', 'it', 'j:', 22)
# -------
# 0x6a72
# ('jr', 'i:', 'it', 'j:', 24)
# -------
# 0x6f6b
# ('ok', 'i:', 'it', 'j:', 26)
# -------
# 0x767a
# ('vz', 'i:', 'it', 'j:', 28)
# -------
# 0x6774
# ('gt', 'i:', 'it', 'j:', 30)
# -------
# 0x6970
# ('ip', 'i:', 'it', 'j:', 32)
# -------
# 0x6d69
# ('mi', 'i:', 'it', 'j:', 34)
# -------
# 0x743b
# ('t;', 'i:', 'it', 'j:', 36)
# -------
# 0x2661
# ('&a', 'i:', 'it', 'j:', 38)
# -------
# 0x7c77
# ('|w', 'i:', 'it', 'j:', 40)
# -------
# 0x6a63
# ('jc', 'i:', 'it', 'j:', 42)
# -------
# 0x7e72
# ('~r', 'i:', 'it', 'j:', 44)
# -------
# 0x402125
# ('@!%', 'i:', 'for', 'j:', 0)
# -------
# 0x283867
# ('(8g', 'i:', 'for', 'j:', 2)
# -------
# 0x317a74
# ('1zt', 'i:', 'for', 'j:', 4)
# -------
# 0x73696f
# ('sio', 'i:', 'for', 'j:', 6)
# -------
# 0x607221
# ('`r!', 'i:', 'for', 'j:', 8)
# -------
# 0x7b3c3f
# ('{<?', 'i:', 'for', 'j:', 10)
# -------
# 0x352275
# ('5"u', 'i:', 'for', 'j:', 12)
# -------
# 0x2b686f
# ('+ho', 'i:', 'for', 'j:', 14)
# -------
# 0x61727a
# ('arz', 'i:', 'for', 'j:', 16)
# -------
# 0x7b6737
# ('{g7', 'i:', 'for', 'j:', 18)
# -------
# 0x6e2a71
# ('n*q', 'i:', 'for', 'j:', 20)
# -------
# 0x236c74
# ('#lt', 'i:', 'for', 'j:', 22)
# -------
# 0x65696d
# ('eim', 'i:', 'for', 'j:', 24)
# -------
# 0x60707c
# ('`p|', 'i:', 'for', 'j:', 26)
# -------
# 0x796172
# ('yar', 'i:', 'for', 'j:', 28)
# -------
# 0x686f76
# ('hov', 'i:', 'for', 'j:', 30)
# -------
# 0x666b6f
# ('fko', 'i:', 'for', 'j:', 32)
# -------
# 0x62723d
# ('br=', 'i:', 'for', 'j:', 34)
# -------
# 0x7b2067
# ('{ g', 'i:', 'for', 'j:', 36)
# -------
# 0x297a71
# (')zq', 'i:', 'for', 'j:', 38)
# -------
# 0x736c65
# ('sle', 'i:', 'for', 'j:', 40)
# -------
# 0x657874
# ('ext', 'i:', 'for', 'j:', 42)
# -------
# 0x482123
# ('H!#', 'i:', 'not', 'j:', 0)
# -------
# 0x203861
# (' 8a', 'i:', 'not', 'j:', 2)
# -------
# 0x397a72
# ('9zr', 'i:', 'not', 'j:', 4)
# -------
# 0x7b6969
# ('{ii', 'i:', 'not', 'j:', 6)
# -------
# 0x687227
# ("hr'", 'i:', 'not', 'j:', 8)
# -------
# 0x733c39
# ('s<9', 'i:', 'not', 'j:', 10)
# -------
# 0x3d2273
# ('="s', 'i:', 'not', 'j:', 12)
# -------
# 0x236869
# ('#hi', 'i:', 'not', 'j:', 14)
# -------
# 0x69727c
# ('ir|', 'i:', 'not', 'j:', 16)
# -------
# 0x736731
# ('sg1', 'i:', 'not', 'j:', 18)
# -------
# 0x662a77
# ('f*w', 'i:', 'not', 'j:', 20)
# -------
# 0x2b6c72
# ('+lr', 'i:', 'not', 'j:', 22)
# -------
# 0x6d696b
# ('mik', 'i:', 'not', 'j:', 24)
# -------
# 0x68707a
# ('hpz', 'i:', 'not', 'j:', 26)
# -------
# 0x716174
# ('qat', 'i:', 'not', 'j:', 28)
# -------
# 0x606f70
# ('`op', 'i:', 'not', 'j:', 30)
# -------
# 0x6e6b69
# ('nki', 'i:', 'not', 'j:', 32)
# -------
# 0x6a723b
# ('jr;', 'i:', 'not', 'j:', 34)
# -------
# 0x732061
# ('s a', 'i:', 'not', 'j:', 36)
# -------
# 0x217a77
# ('!zw', 'i:', 'not', 'j:', 38)
# -------
# 0x7b6c63
# ('{lc', 'i:', 'not', 'j:', 40)
# -------
# 0x6d7872
# ('mxr', 'i:', 'not', 'j:', 42)
# -------
# 0x4920
# ('I ', 'i:', 'on', 'j:', 0)
# -------
# 0x2139
# ('!9', 'i:', 'on', 'j:', 2)
# -------
# 0x387b
# ('8{', 'i:', 'on', 'j:', 4)
# -------
# 0x7a68
# ('zh', 'i:', 'on', 'j:', 6)
# -------
# 0x6973
# ('is', 'i:', 'on', 'j:', 8)
# -------
# 0x723d
# ('r=', 'i:', 'on', 'j:', 10)
# -------
# 0x3c23
# ('<#', 'i:', 'on', 'j:', 12)
# -------
# 0x2269
# ('"i', 'i:', 'on', 'j:', 14)
# -------
# 0x6873
# ('hs', 'i:', 'on', 'j:', 16)
# -------
# 0x7266
# ('rf', 'i:', 'on', 'j:', 18)
# -------
# 0x672b
# ('g+', 'i:', 'on', 'j:', 20)
# -------
# 0x2a6d
# ('*m', 'i:', 'on', 'j:', 22)
# -------
# 0x6c68
# ('lh', 'i:', 'on', 'j:', 24)
# -------
# 0x6971
# ('iq', 'i:', 'on', 'j:', 26)
# -------
# 0x7060
# ('p`', 'i:', 'on', 'j:', 28)
# -------
# 0x616e
# ('an', 'i:', 'on', 'j:', 30)
# -------
# 0x6f6a
# ('oj', 'i:', 'on', 'j:', 32)
# -------
# 0x6b73
# ('ks', 'i:', 'on', 'j:', 34)
# -------
# 0x7221
# ('r!', 'i:', 'on', 'j:', 36)
# -------
# 0x207b
# (' {', 'i:', 'on', 'j:', 38)
# -------
# 0x7a6d
# ('zm', 'i:', 'on', 'j:', 40)
# -------
# 0x6c79
# ('ly', 'i:', 'on', 'j:', 42)
# -------
# 0x7868
# ('xh', 'i:', 'on', 'j:', 44)
# -------
# 0x5127237d
# ("Q'#}", 'i:', 'with', 'j:', 0)
# -------
# 0x393e616e
# ('9>an', 'i:', 'with', 'j:', 2)
# -------
# 0x207c7275
# (' |ru', 'i:', 'with', 'j:', 4)
# -------
# 0x626f693b
# ('boi;', 'i:', 'with', 'j:', 6)
# -------
# 0x71742725
# ("qt'%", 'i:', 'with', 'j:', 8)
# -------
# 0x6a3a396f
# ('j:9o', 'i:', 'with', 'j:', 10)
# -------
# 0x24247375
# ('$$su', 'i:', 'with', 'j:', 12)
# -------
# 0x3a6e6960
# (':ni`', 'i:', 'with', 'j:', 14)
# -------
# 0x70747c2d
# ('pt|-', 'i:', 'with', 'j:', 16)
# -------
# 0x6a61316b
# ('ja1k', 'i:', 'with', 'j:', 18)
# -------
# 0x7f2c776e
# ('\x7f,wn', 'i:', 'with', 'j:', 20)
# -------
# 0x326a7277
# ('2jrw', 'i:', 'with', 'j:', 22)
# -------
# 0x746f6b66
# ('tokf', 'i:', 'with', 'j:', 24)
# -------
# 0x71767a68
# ('qvzh', 'i:', 'with', 'j:', 26)
# -------
# 0x6867746c
# ('hgtl', 'i:', 'with', 'j:', 28)
# -------
# 0x79697075
# ('yipu', 'i:', 'with', 'j:', 30)
# -------
# 0x776d6927
# ("wmi'", 'i:', 'with', 'j:', 32)
# -------
# 0x73743b7d
# ('st;}', 'i:', 'with', 'j:', 34)
# -------
# 0x6a26616b
# ('j&ak', 'i:', 'with', 'j:', 36)
# -------
# 0x387c777f
# ('8|w\x7f', 'i:', 'with', 'j:', 38)
# -------
# 0x626a636e
# ('bjcn', 'i:', 'with', 'j:', 40)
# -------
# 0x4e2b
# ('N+', 'i:', 'he', 'j:', 0)
# -------
# 0x2632
# ('&2', 'i:', 'he', 'j:', 2)
# -------
# 0x3f70
# ('?p', 'i:', 'he', 'j:', 4)
# -------
# 0x7d63
# ('}c', 'i:', 'he', 'j:', 6)
# -------
# 0x6e78
# ('nx', 'i:', 'he', 'j:', 8)
# -------
# 0x7536
# ('u6', 'i:', 'he', 'j:', 10)
# -------
# 0x3b28
# (';(', 'i:', 'he', 'j:', 12)
# -------
# 0x2562
# ('%b', 'i:', 'he', 'j:', 14)
# -------
# 0x6f78
# ('ox', 'i:', 'he', 'j:', 16)
# -------
# 0x756d
# ('um', 'i:', 'he', 'j:', 18)
# -------
# 0x6020
# ('` ', 'i:', 'he', 'j:', 20)
# -------
# 0x2d66
# ('-f', 'i:', 'he', 'j:', 22)
# -------
# 0x6b63
# ('kc', 'i:', 'he', 'j:', 24)
# -------
# 0x6e7a
# ('nz', 'i:', 'he', 'j:', 26)
# -------
# 0x776b
# ('wk', 'i:', 'he', 'j:', 28)
# -------
# 0x6665
# ('fe', 'i:', 'he', 'j:', 30)
# -------
# 0x6861
# ('ha', 'i:', 'he', 'j:', 32)
# -------
# 0x6c78
# ('lx', 'i:', 'he', 'j:', 34)
# -------
# 0x752a
# ('u*', 'i:', 'he', 'j:', 36)
# -------
# 0x2770
# ("'p", 'i:', 'he', 'j:', 38)
# -------
# 0x7d66
# ('}f', 'i:', 'he', 'j:', 40)
# -------
# 0x6b72
# ('kr', 'i:', 'he', 'j:', 42)
# -------
# 0x7f63
# ('\x7fc', 'i:', 'he', 'j:', 44)
# -------
# 0x473d
# ('G=', 'i:', 'as', 'j:', 0)
# -------
# 0x2f24
# ('/$', 'i:', 'as', 'j:', 2)
# -------
# 0x3666
# ('6f', 'i:', 'as', 'j:', 4)
# -------
# 0x7475
# ('tu', 'i:', 'as', 'j:', 6)
# -------
# 0x676e
# ('gn', 'i:', 'as', 'j:', 8)
# -------
# 0x7c20
# ('| ', 'i:', 'as', 'j:', 10)
# -------
# 0x323e
# ('2>', 'i:', 'as', 'j:', 12)
# -------
# 0x2c74
# (',t', 'i:', 'as', 'j:', 14)
# -------
# 0x666e
# ('fn', 'i:', 'as', 'j:', 16)
# -------
# 0x7c7b
# ('|{', 'i:', 'as', 'j:', 18)
# -------
# 0x6936
# ('i6', 'i:', 'as', 'j:', 20)
# -------
# 0x2470
# ('$p', 'i:', 'as', 'j:', 22)
# -------
# 0x6275
# ('bu', 'i:', 'as', 'j:', 24)
# -------
# 0x676c
# ('gl', 'i:', 'as', 'j:', 26)
# -------
# 0x7e7d
# ('~}', 'i:', 'as', 'j:', 28)
# -------
# 0x6f73
# ('os', 'i:', 'as', 'j:', 30)
# -------
# 0x6177
# ('aw', 'i:', 'as', 'j:', 32)
# -------
# 0x656e
# ('en', 'i:', 'as', 'j:', 34)
# -------
# 0x7c3c
# ('|<', 'i:', 'as', 'j:', 36)
# -------
# 0x2e66
# ('.f', 'i:', 'as', 'j:', 38)
# -------
# 0x7470
# ('tp', 'i:', 'as', 'j:', 40)
# -------
# 0x6264
# ('bd', 'i:', 'as', 'j:', 42)
# -------
# 0x7675
# ('vu', 'i:', 'as', 'j:', 44)
# -------
# 0x5f2122
# ('_!"', 'i:', 'you', 'j:', 0)
# -------
# 0x373860
# ('78`', 'i:', 'you', 'j:', 2)
# -------
# 0x2e7a73
# ('.zs', 'i:', 'you', 'j:', 4)
# -------
# 0x6c6968
# ('lih', 'i:', 'you', 'j:', 6)
# -------
# 0x7f7226
# ('\x7fr&', 'i:', 'you', 'j:', 8)
# -------
# 0x643c38
# ('d<8', 'i:', 'you', 'j:', 10)
# -------
# 0x2a2272
# ('*"r', 'i:', 'you', 'j:', 12)
# -------
# 0x346868
# ('4hh', 'i:', 'you', 'j:', 14)
# -------
# 0x7e727d
# ('~r}', 'i:', 'you', 'j:', 16)
# -------
# 0x646730
# ('dg0', 'i:', 'you', 'j:', 18)
# -------
# 0x712a76
# ('q*v', 'i:', 'you', 'j:', 20)
# -------
# 0x3c6c73
# ('<ls', 'i:', 'you', 'j:', 22)
# -------
# 0x7a696a
# ('zij', 'i:', 'you', 'j:', 24)
# -------
# 0x7f707b
# ('\x7fp{', 'i:', 'you', 'j:', 26)
# -------
# 0x666175
# ('fau', 'i:', 'you', 'j:', 28)
# -------
# 0x776f71
# ('woq', 'i:', 'you', 'j:', 30)
# -------
# 0x796b68
# ('ykh', 'i:', 'you', 'j:', 32)
# -------
# 0x7d723a
# ('}r:', 'i:', 'you', 'j:', 34)
# -------
# 0x642060
# ('d `', 'i:', 'you', 'j:', 36)
# -------
# 0x367a76
# ('6zv', 'i:', 'you', 'j:', 38)
# -------
# 0x6c6c62
# ('llb', 'i:', 'you', 'j:', 40)
# -------
# 0x7a7873
# ('zxs', 'i:', 'you', 'j:', 42)
# -------
# 0x4221
# ('B!', 'i:', 'do', 'j:', 0)
# -------
# 0x2a38
# ('*8', 'i:', 'do', 'j:', 2)
# -------
# 0x337a
# ('3z', 'i:', 'do', 'j:', 4)
# -------
# 0x7169
# ('qi', 'i:', 'do', 'j:', 6)
# -------
# 0x6272
# ('br', 'i:', 'do', 'j:', 8)
# -------
# 0x793c
# ('y<', 'i:', 'do', 'j:', 10)
# -------
# 0x3722
# ('7"', 'i:', 'do', 'j:', 12)
# -------
# 0x2968
# (')h', 'i:', 'do', 'j:', 14)
# -------
# 0x6372
# ('cr', 'i:', 'do', 'j:', 16)
# -------
# 0x7967
# ('yg', 'i:', 'do', 'j:', 18)
# -------
# 0x6c2a
# ('l*', 'i:', 'do', 'j:', 20)
# -------
# 0x216c
# ('!l', 'i:', 'do', 'j:', 22)
# -------
# 0x6769
# ('gi', 'i:', 'do', 'j:', 24)
# -------
# 0x6270
# ('bp', 'i:', 'do', 'j:', 26)
# -------
# 0x7b61
# ('{a', 'i:', 'do', 'j:', 28)
# -------
# 0x6a6f
# ('jo', 'i:', 'do', 'j:', 30)
# -------
# 0x646b
# ('dk', 'i:', 'do', 'j:', 32)
# -------
# 0x6072
# ('`r', 'i:', 'do', 'j:', 34)
# -------
# 0x7920
# ('y ', 'i:', 'do', 'j:', 36)
# -------
# 0x2b7a
# ('+z', 'i:', 'do', 'j:', 38)
# -------
# 0x716c
# ('ql', 'i:', 'do', 'j:', 40)
# -------
# 0x6778
# ('gx', 'i:', 'do', 'j:', 42)
# -------
# 0x7369
# ('si', 'i:', 'do', 'j:', 44)
# -------
# 0x473a
# ('G:', 'i:', 'at', 'j:', 0)
# -------
# 0x2f23
# ('/#', 'i:', 'at', 'j:', 2)
# -------
# 0x3661
# ('6a', 'i:', 'at', 'j:', 4)
# -------
# 0x7472
# ('tr', 'i:', 'at', 'j:', 6)
# -------
# 0x6769
# ('gi', 'i:', 'at', 'j:', 8)
# -------
# 0x7c27
# ("|'", 'i:', 'at', 'j:', 10)
# -------
# 0x3239
# ('29', 'i:', 'at', 'j:', 12)
# -------
# 0x2c73
# (',s', 'i:', 'at', 'j:', 14)
# -------
# 0x6669
# ('fi', 'i:', 'at', 'j:', 16)
# -------
# 0x7c7c
# ('||', 'i:', 'at', 'j:', 18)
# -------
# 0x6931
# ('i1', 'i:', 'at', 'j:', 20)
# -------
# 0x2477
# ('$w', 'i:', 'at', 'j:', 22)
# -------
# 0x6272
# ('br', 'i:', 'at', 'j:', 24)
# -------
# 0x676b
# ('gk', 'i:', 'at', 'j:', 26)
# -------
# 0x7e7a
# ('~z', 'i:', 'at', 'j:', 28)
# -------
# 0x6f74
# ('ot', 'i:', 'at', 'j:', 30)
# -------
# 0x6170
# ('ap', 'i:', 'at', 'j:', 32)
# -------
# 0x6569
# ('ei', 'i:', 'at', 'j:', 34)
# -------
# 0x7c3b
# ('|;', 'i:', 'at', 'j:', 36)
# -------
# 0x2e61
# ('.a', 'i:', 'at', 'j:', 38)
# -------
# 0x7477
# ('tw', 'i:', 'at', 'j:', 40)
# -------
# 0x6263
# ('bc', 'i:', 'at', 'j:', 42)
# -------
# 0x7672
# ('vr', 'i:', 'at', 'j:', 44)
# -------
# 0x52263e66
# ('R&>f', 'i:', 'this', 'j:', 0)
# -------
# 0x3a3f7c75
# (':?|u', 'i:', 'this', 'j:', 2)
# -------
# 0x237d6f6e
# ('#}on', 'i:', 'this', 'j:', 4)
# -------
# 0x616e7420
# ('ant ', 'i:', 'this', 'j:', 6)
# -------
# 0x72753a3e
# ('ru:>', 'i:', 'this', 'j:', 8)
# -------
# 0x693b2474
# ('i;$t', 'i:', 'this', 'j:', 10)
# -------
# 0x27256e6e
# ("'%nn", 'i:', 'this', 'j:', 12)
# -------
# 0x396f747b
# ('9ot{', 'i:', 'this', 'j:', 14)
# -------
# 0x73756136
# ('sua6', 'i:', 'this', 'j:', 16)
# -------
# 0x69602c70
# ('i`,p', 'i:', 'this', 'j:', 18)
# -------
# 0x7c2d6a75
# ('|-ju', 'i:', 'this', 'j:', 20)
# -------
# 0x316b6f6c
# ('1kol', 'i:', 'this', 'j:', 22)
# -------
# 0x776e767d
# ('wnv}', 'i:', 'this', 'j:', 24)
# -------
# 0x72776773
# ('rwgs', 'i:', 'this', 'j:', 26)
# -------
# 0x6b666977
# ('kfiw', 'i:', 'this', 'j:', 28)
# -------
# 0x7a686d6e
# ('zhmn', 'i:', 'this', 'j:', 30)
# -------
# 0x746c743c
# ('tlt<', 'i:', 'this', 'j:', 32)
# -------
# 0x70752666
# ('pu&f', 'i:', 'this', 'j:', 34)
# -------
# 0x69277c70
# ("i'|p", 'i:', 'this', 'j:', 36)
# -------
# 0x3b7d6a64
# (';}jd', 'i:', 'this', 'j:', 38)
# -------
# 0x616b7e75
# ('ak~u', 'i:', 'this', 'j:', 40)
# -------
# 0x443b23
# ('D;#', 'i:', 'but', 'j:', 0)
# -------
# 0x2c2261
# (',"a', 'i:', 'but', 'j:', 2)
# -------
# 0x356072
# ('5`r', 'i:', 'but', 'j:', 4)
# -------
# 0x777369
# ('wsi', 'i:', 'but', 'j:', 6)
# -------
# 0x646827
# ("dh'", 'i:', 'but', 'j:', 8)
# -------
# 0x7f2639
# ('\x7f&9', 'i:', 'but', 'j:', 10)
# -------
# 0x313873
# ('18s', 'i:', 'but', 'j:', 12)
# -------
# 0x2f7269
# ('/ri', 'i:', 'but', 'j:', 14)
# -------
# 0x65687c
# ('eh|', 'i:', 'but', 'j:', 16)
# -------
# 0x7f7d31
# ('\x7f}1', 'i:', 'but', 'j:', 18)
# -------
# 0x6a3077
# ('j0w', 'i:', 'but', 'j:', 20)
# -------
# 0x277672
# ("'vr", 'i:', 'but', 'j:', 22)
# -------
# 0x61736b
# ('ask', 'i:', 'but', 'j:', 24)
# -------
# 0x646a7a
# ('djz', 'i:', 'but', 'j:', 26)
# -------
# 0x7d7b74
# ('}{t', 'i:', 'but', 'j:', 28)
# -------
# 0x6c7570
# ('lup', 'i:', 'but', 'j:', 30)
# -------
# 0x627169
# ('bqi', 'i:', 'but', 'j:', 32)
# -------
# 0x66683b
# ('fh;', 'i:', 'but', 'j:', 34)
# -------
# 0x7f3a61
# ('\x7f:a', 'i:', 'but', 'j:', 36)
# -------
# 0x2d6077
# ('-`w', 'i:', 'but', 'j:', 38)
# -------
# 0x777663
# ('wvc', 'i:', 'but', 'j:', 40)
# -------
# 0x616272
# ('abr', 'i:', 'but', 'j:', 42)
# -------
# 0x4e2724
# ("N'$", 'i:', 'his', 'j:', 0)
# -------
# 0x263e66
# ('&>f', 'i:', 'his', 'j:', 2)
# -------
# 0x3f7c75
# ('?|u', 'i:', 'his', 'j:', 4)
# -------
# 0x7d6f6e
# ('}on', 'i:', 'his', 'j:', 6)
# -------
# 0x6e7420
# ('nt ', 'i:', 'his', 'j:', 8)
# -------
# 0x753a3e
# ('u:>', 'i:', 'his', 'j:', 10)
# -------
# 0x3b2474
# (';$t', 'i:', 'his', 'j:', 12)
# -------
# 0x256e6e
# ('%nn', 'i:', 'his', 'j:', 14)
# -------
# 0x6f747b
# ('ot{', 'i:', 'his', 'j:', 16)
# -------
# 0x756136
# ('ua6', 'i:', 'his', 'j:', 18)
# -------
# 0x602c70
# ('`,p', 'i:', 'his', 'j:', 20)
# -------
# 0x2d6a75
# ('-ju', 'i:', 'his', 'j:', 22)
# -------
# 0x6b6f6c
# ('kol', 'i:', 'his', 'j:', 24)
# -------
# 0x6e767d
# ('nv}', 'i:', 'his', 'j:', 26)
# -------
# 0x776773
# ('wgs', 'i:', 'his', 'j:', 28)
# -------
# 0x666977
# ('fiw', 'i:', 'his', 'j:', 30)
# -------
# 0x686d6e
# ('hmn', 'i:', 'his', 'j:', 32)
# -------
# 0x6c743c
# ('lt<', 'i:', 'his', 'j:', 34)
# -------
# 0x752666
# ('u&f', 'i:', 'his', 'j:', 36)
# -------
# 0x277c70
# ("'|p", 'i:', 'his', 'j:', 38)
# -------
# 0x7d6a64
# ('}jd', 'i:', 'his', 'j:', 40)
# -------
# 0x6b7e75
# ('k~u', 'i:', 'his', 'j:', 42)
# -------
# 0x4437
# ('D7', 'i:', 'by', 'j:', 0)
# -------
# 0x2c2e
# (',.', 'i:', 'by', 'j:', 2)
# -------
# 0x356c
# ('5l', 'i:', 'by', 'j:', 4)
# -------
# 0x777f
# ('w\x7f', 'i:', 'by', 'j:', 6)
# -------
# 0x6464
# ('dd', 'i:', 'by', 'j:', 8)
# -------
# 0x7f2a
# ('\x7f*', 'i:', 'by', 'j:', 10)
# -------
# 0x3134
# ('14', 'i:', 'by', 'j:', 12)
# -------
# 0x2f7e
# ('/~', 'i:', 'by', 'j:', 14)
# -------
# 0x6564
# ('ed', 'i:', 'by', 'j:', 16)
# -------
# 0x7f71
# ('\x7fq', 'i:', 'by', 'j:', 18)
# -------
# 0x6a3c
# ('j<', 'i:', 'by', 'j:', 20)
# -------
# 0x277a
# ("'z", 'i:', 'by', 'j:', 22)
# -------
# 0x617f
# ('a\x7f', 'i:', 'by', 'j:', 24)
# -------
# 0x6466
# ('df', 'i:', 'by', 'j:', 26)
# -------
# 0x7d77
# ('}w', 'i:', 'by', 'j:', 28)
# -------
# 0x6c79
# ('ly', 'i:', 'by', 'j:', 30)
# -------
# 0x627d
# ('b}', 'i:', 'by', 'j:', 32)
# -------
# 0x6664
# ('fd', 'i:', 'by', 'j:', 34)
# -------
# 0x7f36
# ('\x7f6', 'i:', 'by', 'j:', 36)
# -------
# 0x2d6c
# ('-l', 'i:', 'by', 'j:', 38)
# -------
# 0x777a
# ('wz', 'i:', 'by', 'j:', 40)
# -------
# 0x616e
# ('an', 'i:', 'by', 'j:', 42)
# -------
# 0x757f
# ('u\x7f', 'i:', 'by', 'j:', 44)
# -------
# 0x403c3878
# ('@<8x', 'i:', 'from', 'j:', 0)
# -------
# 0x28257a6b
# ('(%zk', 'i:', 'from', 'j:', 2)
# -------
# 0x31676970
# ('1gip', 'i:', 'from', 'j:', 4)
# -------
# 0x7374723e
# ('str>', 'i:', 'from', 'j:', 6)
# -------
# 0x606f3c20
# ('`o< ', 'i:', 'from', 'j:', 8)
# -------
# 0x7b21226a
# ('{!"j', 'i:', 'from', 'j:', 10)
# -------
# 0x353f6870
# ('5?hp', 'i:', 'from', 'j:', 12)
# -------
# 0x2b757265
# ('+ure', 'i:', 'from', 'j:', 14)
# -------
# 0x616f6728
# ('aog(', 'i:', 'from', 'j:', 16)
# -------
# 0x7b7a2a6e
# ('{z*n', 'i:', 'from', 'j:', 18)
# -------
# 0x6e376c6b
# ('n7lk', 'i:', 'from', 'j:', 20)
# -------
# 0x23716972
# ('#qir', 'i:', 'from', 'j:', 22)
# -------
# 0x65747063
# ('etpc', 'i:', 'from', 'j:', 24)
# -------
# 0x606d616d
# ('`mam', 'i:', 'from', 'j:', 26)
# -------
# 0x797c6f69
# ('y|oi', 'i:', 'from', 'j:', 28)
# -------
# 0x68726b70
# ('hrkp', 'i:', 'from', 'j:', 30)
# -------
# 0x66767222
# ('fvr"', 'i:', 'from', 'j:', 32)
# -------
# 0x626f2078
# ('bo x', 'i:', 'from', 'j:', 34)
# -------
# 0x7b3d7a6e
# ('{=zn', 'i:', 'from', 'j:', 36)
# -------
# 0x29676c7a
# (')glz', 'i:', 'from', 'j:', 38)
# -------
# 0x7371786b
# ('sqxk', 'i:', 'from', 'j:', 40)
# -------
# 0x5226326c
# ('R&2l', 'i:', 'they', 'j:', 0)
# -------
# 0x3a3f707f
# (':?p\x7f', 'i:', 'they', 'j:', 2)
# -------
# 0x237d6364
# ('#}cd', 'i:', 'they', 'j:', 4)
# -------
# 0x616e782a
# ('anx*', 'i:', 'they', 'j:', 6)
# -------
# 0x72753634
# ('ru64', 'i:', 'they', 'j:', 8)
# -------
# 0x693b287e
# ('i;(~', 'i:', 'they', 'j:', 10)
# -------
# 0x27256264
# ("'%bd", 'i:', 'they', 'j:', 12)
# -------
# 0x396f7871
# ('9oxq', 'i:', 'they', 'j:', 14)
# -------
# 0x73756d3c
# ('sum<', 'i:', 'they', 'j:', 16)
# -------
# 0x6960207a
# ('i` z', 'i:', 'they', 'j:', 18)
# -------
# 0x7c2d667f
# ('|-f\x7f', 'i:', 'they', 'j:', 20)
# -------
# 0x316b6366
# ('1kcf', 'i:', 'they', 'j:', 22)
# -------
# 0x776e7a77
# ('wnzw', 'i:', 'they', 'j:', 24)
# -------
# 0x72776b79
# ('rwky', 'i:', 'they', 'j:', 26)
# -------
# 0x6b66657d
# ('kfe}', 'i:', 'they', 'j:', 28)
# -------
# 0x7a686164
# ('zhad', 'i:', 'they', 'j:', 30)
# -------
# 0x746c7836
# ('tlx6', 'i:', 'they', 'j:', 32)
# -------
# 0x70752a6c
# ('pu*l', 'i:', 'they', 'j:', 34)
# -------
# 0x6927707a
# ("i'pz", 'i:', 'they', 'j:', 36)
# -------
# 0x3b7d666e
# (';}fn', 'i:', 'they', 'j:', 38)
# -------
# 0x616b727f
# ('akr\x7f', 'i:', 'they', 'j:', 40)
# -------
# 0x512b
# ('Q+', 'i:', 'we', 'j:', 0)
# -------
# 0x3932
# ('92', 'i:', 'we', 'j:', 2)
# -------
# 0x2070
# (' p', 'i:', 'we', 'j:', 4)
# -------
# 0x6263
# ('bc', 'i:', 'we', 'j:', 6)
# -------
# 0x7178
# ('qx', 'i:', 'we', 'j:', 8)
# -------
# 0x6a36
# ('j6', 'i:', 'we', 'j:', 10)
# -------
# 0x2428
# ('$(', 'i:', 'we', 'j:', 12)
# -------
# 0x3a62
# (':b', 'i:', 'we', 'j:', 14)
# -------
# 0x7078
# ('px', 'i:', 'we', 'j:', 16)
# -------
# 0x6a6d
# ('jm', 'i:', 'we', 'j:', 18)
# -------
# 0x7f20
# ('\x7f ', 'i:', 'we', 'j:', 20)
# -------
# 0x3266
# ('2f', 'i:', 'we', 'j:', 22)
# -------
# 0x7463
# ('tc', 'i:', 'we', 'j:', 24)
# -------
# 0x717a
# ('qz', 'i:', 'we', 'j:', 26)
# -------
# 0x686b
# ('hk', 'i:', 'we', 'j:', 28)
# -------
# 0x7965
# ('ye', 'i:', 'we', 'j:', 30)
# -------
# 0x7761
# ('wa', 'i:', 'we', 'j:', 32)
# -------
# 0x7378
# ('sx', 'i:', 'we', 'j:', 34)
# -------
# 0x6a2a
# ('j*', 'i:', 'we', 'j:', 36)
# -------
# 0x3870
# ('8p', 'i:', 'we', 'j:', 38)
# -------
# 0x6266
# ('bf', 'i:', 'we', 'j:', 40)
# -------
# 0x7472
# ('tr', 'i:', 'we', 'j:', 42)
# -------
# 0x6063
# ('`c', 'i:', 'we', 'j:', 44)
# -------
# 0x552f2e
# ('U/.', 'i:', 'say', 'j:', 0)
# -------
# 0x3d366c
# ('=6l', 'i:', 'say', 'j:', 2)
# -------
# 0x24747f
# ('$t\x7f', 'i:', 'say', 'j:', 4)
# -------
# 0x666764
# ('fgd', 'i:', 'say', 'j:', 6)
# -------
# 0x757c2a
# ('u|*', 'i:', 'say', 'j:', 8)
# -------
# 0x6e3234
# ('n24', 'i:', 'say', 'j:', 10)
# -------
# 0x202c7e
# (' ,~', 'i:', 'say', 'j:', 12)
# -------
# 0x3e6664
# ('>fd', 'i:', 'say', 'j:', 14)
# -------
# 0x747c71
# ('t|q', 'i:', 'say', 'j:', 16)
# -------
# 0x6e693c
# ('ni<', 'i:', 'say', 'j:', 18)
# -------
# 0x7b247a
# ('{$z', 'i:', 'say', 'j:', 20)
# -------
# 0x36627f
# ('6b\x7f', 'i:', 'say', 'j:', 22)
# -------
# 0x706766
# ('pgf', 'i:', 'say', 'j:', 24)
# -------
# 0x757e77
# ('u~w', 'i:', 'say', 'j:', 26)
# -------
# 0x6c6f79
# ('loy', 'i:', 'say', 'j:', 28)
# -------
# 0x7d617d
# ('}a}', 'i:', 'say', 'j:', 30)
# -------
# 0x736564
# ('sed', 'i:', 'say', 'j:', 32)
# -------
# 0x777c36
# ('w|6', 'i:', 'say', 'j:', 34)
# -------
# 0x6e2e6c
# ('n.l', 'i:', 'say', 'j:', 36)
# -------
# 0x3c747a
# ('<tz', 'i:', 'say', 'j:', 38)
# -------
# 0x66626e
# ('fbn', 'i:', 'say', 'j:', 40)
# -------
# 0x70767f
# ('pv\x7f', 'i:', 'say', 'j:', 42)
# -------
# 0x4e2b25
# ('N+%', 'i:', 'her', 'j:', 0)
# -------
# 0x263267
# ('&2g', 'i:', 'her', 'j:', 2)
# -------
# 0x3f7074
# ('?pt', 'i:', 'her', 'j:', 4)
# -------
# 0x7d636f
# ('}co', 'i:', 'her', 'j:', 6)
# -------
# 0x6e7821
# ('nx!', 'i:', 'her', 'j:', 8)
# -------
# 0x75363f
# ('u6?', 'i:', 'her', 'j:', 10)
# -------
# 0x3b2875
# (';(u', 'i:', 'her', 'j:', 12)
# -------
# 0x25626f
# ('%bo', 'i:', 'her', 'j:', 14)
# -------
# 0x6f787a
# ('oxz', 'i:', 'her', 'j:', 16)
# -------
# 0x756d37
# ('um7', 'i:', 'her', 'j:', 18)
# -------
# 0x602071
# ('` q', 'i:', 'her', 'j:', 20)
# -------
# 0x2d6674
# ('-ft', 'i:', 'her', 'j:', 22)
# -------
# 0x6b636d
# ('kcm', 'i:', 'her', 'j:', 24)
# -------
# 0x6e7a7c
# ('nz|', 'i:', 'her', 'j:', 26)
# -------
# 0x776b72
# ('wkr', 'i:', 'her', 'j:', 28)
# -------
# 0x666576
# ('fev', 'i:', 'her', 'j:', 30)
# -------
# 0x68616f
# ('hao', 'i:', 'her', 'j:', 32)
# -------
# 0x6c783d
# ('lx=', 'i:', 'her', 'j:', 34)
# -------
# 0x752a67
# ('u*g', 'i:', 'her', 'j:', 36)
# -------
# 0x277071
# ("'pq", 'i:', 'her', 'j:', 38)
# -------
# 0x7d6665
# ('}fe', 'i:', 'her', 'j:', 40)
# -------
# 0x6b7274
# ('krt', 'i:', 'her', 'j:', 42)
# -------
# 0x552632
# ('U&2', 'i:', 'she', 'j:', 0)
# -------
# 0x3d3f70
# ('=?p', 'i:', 'she', 'j:', 2)
# -------
# 0x247d63
# ('$}c', 'i:', 'she', 'j:', 4)
# -------
# 0x666e78
# ('fnx', 'i:', 'she', 'j:', 6)
# -------
# 0x757536
# ('uu6', 'i:', 'she', 'j:', 8)
# -------
# 0x6e3b28
# ('n;(', 'i:', 'she', 'j:', 10)
# -------
# 0x202562
# (' %b', 'i:', 'she', 'j:', 12)
# -------
# 0x3e6f78
# ('>ox', 'i:', 'she', 'j:', 14)
# -------
# 0x74756d
# ('tum', 'i:', 'she', 'j:', 16)
# -------
# 0x6e6020
# ('n` ', 'i:', 'she', 'j:', 18)
# -------
# 0x7b2d66
# ('{-f', 'i:', 'she', 'j:', 20)
# -------
# 0x366b63
# ('6kc', 'i:', 'she', 'j:', 22)
# -------
# 0x706e7a
# ('pnz', 'i:', 'she', 'j:', 24)
# -------
# 0x75776b
# ('uwk', 'i:', 'she', 'j:', 26)
# -------
# 0x6c6665
# ('lfe', 'i:', 'she', 'j:', 28)
# -------
# 0x7d6861
# ('}ha', 'i:', 'she', 'j:', 30)
# -------
# 0x736c78
# ('slx', 'i:', 'she', 'j:', 32)
# -------
# 0x77752a
# ('wu*', 'i:', 'she', 'j:', 34)
# -------
# 0x6e2770
# ("n'p", 'i:', 'she', 'j:', 36)
# -------
# 0x3c7d66
# ('<}f', 'i:', 'she', 'j:', 38)
# -------
# 0x666b72
# ('fkr', 'i:', 'she', 'j:', 40)
# -------
# 0x707f63
# ('p\x7fc', 'i:', 'she', 'j:', 42)
# -------
# 0x493c
# ('I<', 'i:', 'or', 'j:', 0)
# -------
# 0x2125
# ('!%', 'i:', 'or', 'j:', 2)
# -------
# 0x3867
# ('8g', 'i:', 'or', 'j:', 4)
# -------
# 0x7a74
# ('zt', 'i:', 'or', 'j:', 6)
# -------
# 0x696f
# ('io', 'i:', 'or', 'j:', 8)
# -------
# 0x7221
# ('r!', 'i:', 'or', 'j:', 10)
# -------
# 0x3c3f
# ('<?', 'i:', 'or', 'j:', 12)
# -------
# 0x2275
# ('"u', 'i:', 'or', 'j:', 14)
# -------
# 0x686f
# ('ho', 'i:', 'or', 'j:', 16)
# -------
# 0x727a
# ('rz', 'i:', 'or', 'j:', 18)
# -------
# 0x6737
# ('g7', 'i:', 'or', 'j:', 20)
# -------
# 0x2a71
# ('*q', 'i:', 'or', 'j:', 22)
# -------
# 0x6c74
# ('lt', 'i:', 'or', 'j:', 24)
# -------
# 0x696d
# ('im', 'i:', 'or', 'j:', 26)
# -------
# 0x707c
# ('p|', 'i:', 'or', 'j:', 28)
# -------
# 0x6172
# ('ar', 'i:', 'or', 'j:', 30)
# -------
# 0x6f76
# ('ov', 'i:', 'or', 'j:', 32)
# -------
# 0x6b6f
# ('ko', 'i:', 'or', 'j:', 34)
# -------
# 0x723d
# ('r=', 'i:', 'or', 'j:', 36)
# -------
# 0x2067
# (' g', 'i:', 'or', 'j:', 38)
# -------
# 0x7a71
# ('zq', 'i:', 'or', 'j:', 40)
# -------
# 0x6c65
# ('le', 'i:', 'or', 'j:', 42)
# -------
# 0x7874
# ('xt', 'i:', 'or', 'j:', 44)
# -------
# 0x51273b79
# ("Q';y", 'i:', 'will', 'j:', 0)
# -------
# 0x393e796a
# ('9>yj', 'i:', 'will', 'j:', 2)
# -------
# 0x207c6a71
# (' |jq', 'i:', 'will', 'j:', 4)
# -------
# 0x626f713f
# ('boq?', 'i:', 'will', 'j:', 6)
# -------
# 0x71743f21
# ('qt?!', 'i:', 'will', 'j:', 8)
# -------
# 0x6a3a216b
# ('j:!k', 'i:', 'will', 'j:', 10)
# -------
# 0x24246b71
# ('$$kq', 'i:', 'will', 'j:', 12)
# -------
# 0x3a6e7164
# (':nqd', 'i:', 'will', 'j:', 14)
# -------
# 0x70746429
# ('ptd)', 'i:', 'will', 'j:', 16)
# -------
# 0x6a61296f
# ('ja)o', 'i:', 'will', 'j:', 18)
# -------
# 0x7f2c6f6a
# ('\x7f,oj', 'i:', 'will', 'j:', 20)
# -------
# 0x326a6a73
# ('2jjs', 'i:', 'will', 'j:', 22)
# -------
# 0x746f7362
# ('tosb', 'i:', 'will', 'j:', 24)
# -------
# 0x7176626c
# ('qvbl', 'i:', 'will', 'j:', 26)
# -------
# 0x68676c68
# ('hglh', 'i:', 'will', 'j:', 28)
# -------
# 0x79696871
# ('yihq', 'i:', 'will', 'j:', 30)
# -------
# 0x776d7123
# ('wmq#', 'i:', 'will', 'j:', 32)
# -------
# 0x73742379
# ('st#y', 'i:', 'will', 'j:', 34)
# -------
# 0x6a26796f
# ('j&yo', 'i:', 'will', 'j:', 36)
# -------
# 0x387c6f7b
# ('8|o{', 'i:', 'will', 'j:', 38)
# -------
# 0x626a7b6a
# ('bj{j', 'i:', 'will', 'j:', 40)
# -------
# ('\x06/95', 'i:', ' an ', 'j:', 0)
# -------
# 0x6e367b26
# ('n6{&', 'i:', ' an ', 'j:', 2)
# -------
# 0x7774683d
# ('wth=', 'i:', ' an ', 'j:', 4)
# -------
# 0x35677373
# ('5gss', 'i:', ' an ', 'j:', 6)
# -------
# 0x267c3d6d
# ('&|=m', 'i:', ' an ', 'j:', 8)
# -------
# 0x3d322327
# ("=2#'", 'i:', ' an ', 'j:', 10)
# -------
# 0x732c693d
# ('s,i=', 'i:', ' an ', 'j:', 12)
# -------
# 0x6d667328
# ('mfs(', 'i:', ' an ', 'j:', 14)
# -------
# 0x277c6665
# ("'|fe", 'i:', ' an ', 'j:', 16)
# -------
# 0x3d692b23
# ('=i+#', 'i:', ' an ', 'j:', 18)
# -------
# 0x28246d26
# ('($m&', 'i:', ' an ', 'j:', 20)
# -------
# 0x6562683f
# ('ebh?', 'i:', ' an ', 'j:', 22)
# -------
# 0x2367712e
# ('#gq.', 'i:', ' an ', 'j:', 24)
# -------
# 0x267e6020
# ('&~` ', 'i:', ' an ', 'j:', 26)
# -------
# 0x3f6f6e24
# ('?on$', 'i:', ' an ', 'j:', 28)
# -------
# 0x2e616a3d
# ('.aj=', 'i:', ' an ', 'j:', 30)
# -------
# 0x2065736f
# (' eso', 'i:', ' an ', 'j:', 32)
# -------
# 0x247c2135
# ('$|!5', 'i:', ' an ', 'j:', 34)
# -------
# 0x3d2e7b23
# ('=.{#', 'i:', ' an ', 'j:', 36)
# -------
# 0x6f746d37
# ('otm7', 'i:', ' an ', 'j:', 38)
# -------
# 0x35627926
# ('5by&', 'i:', ' an ', 'j:', 40)
# -------
# 0x4b37
# ('K7', 'i:', 'my', 'j:', 0)
# -------
# 0x232e
# ('#.', 'i:', 'my', 'j:', 2)
# -------
# 0x3a6c
# (':l', 'i:', 'my', 'j:', 4)
# -------
# 0x787f
# ('x\x7f', 'i:', 'my', 'j:', 6)
# -------
# 0x6b64
# ('kd', 'i:', 'my', 'j:', 8)
# -------
# 0x702a
# ('p*', 'i:', 'my', 'j:', 10)
# -------
# 0x3e34
# ('>4', 'i:', 'my', 'j:', 12)
# -------
# 0x207e
# (' ~', 'i:', 'my', 'j:', 14)
# -------
# 0x6a64
# ('jd', 'i:', 'my', 'j:', 16)
# -------
# 0x7071
# ('pq', 'i:', 'my', 'j:', 18)
# -------
# 0x653c
# ('e<', 'i:', 'my', 'j:', 20)
# -------
# 0x287a
# ('(z', 'i:', 'my', 'j:', 22)
# -------
# 0x6e7f
# ('n\x7f', 'i:', 'my', 'j:', 24)
# -------
# 0x6b66
# ('kf', 'i:', 'my', 'j:', 26)
# -------
# 0x7277
# ('rw', 'i:', 'my', 'j:', 28)
# -------
# 0x6379
# ('cy', 'i:', 'my', 'j:', 30)
# -------
# 0x6d7d
# ('m}', 'i:', 'my', 'j:', 32)
# -------
# 0x6964
# ('id', 'i:', 'my', 'j:', 34)
# -------
# 0x7036
# ('p6', 'i:', 'my', 'j:', 36)
# -------
# 0x226c
# ('"l', 'i:', 'my', 'j:', 38)
# -------
# 0x787a
# ('xz', 'i:', 'my', 'j:', 40)
# -------
# 0x6e6e
# ('nn', 'i:', 'my', 'j:', 42)
# -------
# 0x7a7f
# ('z\x7f', 'i:', 'my', 'j:', 44)
# -------
# 0x492032
# ('I 2', 'i:', 'one', 'j:', 0)
# -------
# 0x213970
# ('!9p', 'i:', 'one', 'j:', 2)
# -------
# 0x387b63
# ('8{c', 'i:', 'one', 'j:', 4)
# -------
# 0x7a6878
# ('zhx', 'i:', 'one', 'j:', 6)
# -------
# 0x697336
# ('is6', 'i:', 'one', 'j:', 8)
# -------
# 0x723d28
# ('r=(', 'i:', 'one', 'j:', 10)
# -------
# 0x3c2362
# ('<#b', 'i:', 'one', 'j:', 12)
# -------
# 0x226978
# ('"ix', 'i:', 'one', 'j:', 14)
# -------
# 0x68736d
# ('hsm', 'i:', 'one', 'j:', 16)
# -------
# 0x726620
# ('rf ', 'i:', 'one', 'j:', 18)
# -------
# 0x672b66
# ('g+f', 'i:', 'one', 'j:', 20)
# -------
# 0x2a6d63
# ('*mc', 'i:', 'one', 'j:', 22)
# -------
# 0x6c687a
# ('lhz', 'i:', 'one', 'j:', 24)
# -------
# 0x69716b
# ('iqk', 'i:', 'one', 'j:', 26)
# -------
# 0x706065
# ('p`e', 'i:', 'one', 'j:', 28)
# -------
# 0x616e61
# ('ana', 'i:', 'one', 'j:', 30)
# -------
# 0x6f6a78
# ('ojx', 'i:', 'one', 'j:', 32)
# -------
# 0x6b732a
# ('ks*', 'i:', 'one', 'j:', 34)
# -------
# 0x722170
# ('r!p', 'i:', 'one', 'j:', 36)
# -------
# 0x207b66
# (' {f', 'i:', 'one', 'j:', 38)
# -------
# 0x7a6d72
# ('zmr', 'i:', 'one', 'j:', 40)
# -------
# 0x6c7963
# ('lyc', 'i:', 'one', 'j:', 42)
# -------
# 0x47223b
# ('G";', 'i:', 'all', 'j:', 0)
# -------
# 0x2f3b79
# ('/;y', 'i:', 'all', 'j:', 2)
# -------
# 0x36796a
# ('6yj', 'i:', 'all', 'j:', 4)
# -------
# 0x746a71
# ('tjq', 'i:', 'all', 'j:', 6)
# -------
# 0x67713f
# ('gq?', 'i:', 'all', 'j:', 8)
# -------
# 0x7c3f21
# ('|?!', 'i:', 'all', 'j:', 10)
# -------
# 0x32216b
# ('2!k', 'i:', 'all', 'j:', 12)
# -------
# 0x2c6b71
# (',kq', 'i:', 'all', 'j:', 14)
# -------
# 0x667164
# ('fqd', 'i:', 'all', 'j:', 16)
# -------
# 0x7c6429
# ('|d)', 'i:', 'all', 'j:', 18)
# -------
# 0x69296f
# ('i)o', 'i:', 'all', 'j:', 20)
# -------
# 0x246f6a
# ('$oj', 'i:', 'all', 'j:', 22)
# -------
# 0x626a73
# ('bjs', 'i:', 'all', 'j:', 24)
# -------
# 0x677362
# ('gsb', 'i:', 'all', 'j:', 26)
# -------
# 0x7e626c
# ('~bl', 'i:', 'all', 'j:', 28)
# -------
# 0x6f6c68
# ('olh', 'i:', 'all', 'j:', 30)
# -------
# 0x616871
# ('ahq', 'i:', 'all', 'j:', 32)
# -------
# 0x657123
# ('eq#', 'i:', 'all', 'j:', 34)
# -------
# 0x7c2379
# ('|#y', 'i:', 'all', 'j:', 36)
# -------
# 0x2e796f
# ('.yo', 'i:', 'all', 'j:', 38)
# -------
# 0x746f7b
# ('to{', 'i:', 'all', 'j:', 40)
# -------
# 0x627b6a
# ('b{j', 'i:', 'all', 'j:', 42)
# -------
# 0x5121227962
# ('Q!"yb', 'i:', 'would', 'j:', 0)
# -------
# 0x3938606a79
# ('98`jy', 'i:', 'would', 'j:', 2)
# -------
# 0x207a737137
# (' zsq7', 'i:', 'would', 'j:', 4)
# -------
# 0x6269683f29
# ('bih?)', 'i:', 'would', 'j:', 6)
# -------
# 0x7172262163
# ('qr&!c', 'i:', 'would', 'j:', 8)
# -------
# 0x6a3c386b79
# ('j<8ky', 'i:', 'would', 'j:', 10)
# -------
# 0x242272716c
# ('$"rql', 'i:', 'would', 'j:', 12)
# -------
# 0x3a68686421
# (':hhd!', 'i:', 'would', 'j:', 14)
# -------
# 0x70727d2967
# ('pr})g', 'i:', 'would', 'j:', 16)
# -------
# 0x6a67306f62
# ('jg0ob', 'i:', 'would', 'j:', 18)
# -------
# 0x7f2a766a7b
# ('\x7f*vj{', 'i:', 'would', 'j:', 20)
# -------
# 0x326c73736a
# ('2lssj', 'i:', 'would', 'j:', 22)
# -------
# 0x74696a6264
# ('tijbd', 'i:', 'would', 'j:', 24)
# -------
# 0x71707b6c60
# ('qp{l`', 'i:', 'would', 'j:', 26)
# -------
# 0x6861756879
# ('hauhy', 'i:', 'would', 'j:', 28)
# -------
# 0x796f71712b
# ('yoqq+', 'i:', 'would', 'j:', 30)
# -------
# 0x776b682371
# ('wkh#q', 'i:', 'would', 'j:', 32)
# -------
# 0x73723a7967
# ('sr:yg', 'i:', 'would', 'j:', 34)
# -------
# 0x6a20606f73
# ('j `os', 'i:', 'would', 'j:', 36)
# -------
# 0x387a767b62
# ('8zv{b', 'i:', 'would', 'j:', 38)
# -------
# 0x5226326763
# ('R&2gc', 'i:', 'there', 'j:', 0)
# -------
# 0x3a3f707478
# (':?ptx', 'i:', 'there', 'j:', 2)
# -------
# 0x237d636f36
# ('#}co6', 'i:', 'there', 'j:', 4)
# -------
# 0x616e782128
# ('anx!(', 'i:', 'there', 'j:', 6)
# -------
# 0x7275363f62
# ('ru6?b', 'i:', 'there', 'j:', 8)
# -------
# 0x693b287578
# ('i;(ux', 'i:', 'there', 'j:', 10)
# -------
# 0x2725626f6d
# ("'%bom", 'i:', 'there', 'j:', 12)
# -------
# 0x396f787a20
# ('9oxz ', 'i:', 'there', 'j:', 14)
# -------
# 0x73756d3766
# ('sum7f', 'i:', 'there', 'j:', 16)
# -------
# 0x6960207163
# ('i` qc', 'i:', 'there', 'j:', 18)
# -------
# 0x7c2d66747a
# ('|-ftz', 'i:', 'there', 'j:', 20)
# -------
# 0x316b636d6b
# ('1kcmk', 'i:', 'there', 'j:', 22)
# -------
# 0x776e7a7c65
# ('wnz|e', 'i:', 'there', 'j:', 24)
# -------
# 0x72776b7261
# ('rwkra', 'i:', 'there', 'j:', 26)
# -------
# 0x6b66657678
# ('kfevx', 'i:', 'there', 'j:', 28)
# -------
# 0x7a68616f2a
# ('zhao*', 'i:', 'there', 'j:', 30)
# -------
# 0x746c783d70
# ('tlx=p', 'i:', 'there', 'j:', 32)
# -------
# 0x70752a6766
# ('pu*gf', 'i:', 'there', 'j:', 34)
# -------
# 0x6927707172
# ("i'pqr", 'i:', 'there', 'j:', 36)
# -------
# 0x3b7d666563
# (';}fec', 'i:', 'there', 'j:', 38)
# -------
# 0x5226327c74
# ('R&2|t', 'i:', 'their', 'j:', 0)
# -------
# 0x3a3f706f6f
# (':?poo', 'i:', 'their', 'j:', 2)
# -------
# 0x237d637421
# ('#}ct!', 'i:', 'their', 'j:', 4)
# -------
# 0x616e783a3f
# ('anx:?', 'i:', 'their', 'j:', 6)
# -------
# 0x7275362475
# ('ru6$u', 'i:', 'their', 'j:', 8)
# -------
# 0x693b286e6f
# ('i;(no', 'i:', 'their', 'j:', 10)
# -------
# 0x272562747a
# ("'%btz", 'i:', 'their', 'j:', 12)
# -------
# 0x396f786137
# ('9oxa7', 'i:', 'their', 'j:', 14)
# -------
# 0x73756d2c71
# ('sum,q', 'i:', 'their', 'j:', 16)
# -------
# 0x6960206a74
# ('i` jt', 'i:', 'their', 'j:', 18)
# -------
# 0x7c2d666f6d
# ('|-fom', 'i:', 'their', 'j:', 20)
# -------
# 0x316b63767c
# ('1kcv|', 'i:', 'their', 'j:', 22)
# -------
# 0x776e7a6772
# ('wnzgr', 'i:', 'their', 'j:', 24)
# -------
# 0x72776b6976
# ('rwkiv', 'i:', 'their', 'j:', 26)
# -------
# 0x6b66656d6f
# ('kfemo', 'i:', 'their', 'j:', 28)
# -------
# 0x7a6861743d
# ('zhat=', 'i:', 'their', 'j:', 30)
# -------
# 0x746c782667
# ('tlx&g', 'i:', 'their', 'j:', 32)
# -------
# 0x70752a7c71
# ('pu*|q', 'i:', 'their', 'j:', 34)
# -------
# 0x6927706a65
# ("i'pje", 'i:', 'their', 'j:', 36)
# -------
# 0x3b7d667e74
# (';}f~t', 'i:', 'their', 'j:', 38)
# -------
# 0x51263661
# ('Q&6a', 'i:', 'what', 'j:', 0)
# -------
# 0x393f7472
# ('9?tr', 'i:', 'what', 'j:', 2)
# -------
# 0x207d6769
# (' }gi', 'i:', 'what', 'j:', 4)
# -------
# 0x626e7c27
# ("bn|'", 'i:', 'what', 'j:', 6)
# -------
# 0x71753239
# ('qu29', 'i:', 'what', 'j:', 8)
# -------
# 0x6a3b2c73
# ('j;,s', 'i:', 'what', 'j:', 10)
# -------
# 0x24256669
# ('$%fi', 'i:', 'what', 'j:', 12)
# -------
# 0x3a6f7c7c
# (':o||', 'i:', 'what', 'j:', 14)
# -------
# 0x70756931
# ('pui1', 'i:', 'what', 'j:', 16)
# -------
# 0x6a602477
# ('j`$w', 'i:', 'what', 'j:', 18)
# -------
# 0x7f2d6272
# ('\x7f-br', 'i:', 'what', 'j:', 20)
# -------
# 0x326b676b
# ('2kgk', 'i:', 'what', 'j:', 22)
# -------
# 0x746e7e7a
# ('tn~z', 'i:', 'what', 'j:', 24)
# -------
# 0x71776f74
# ('qwot', 'i:', 'what', 'j:', 26)
# -------
# 0x68666170
# ('hfap', 'i:', 'what', 'j:', 28)
# -------
# 0x79686569
# ('yhei', 'i:', 'what', 'j:', 30)
# -------
# 0x776c7c3b
# ('wl|;', 'i:', 'what', 'j:', 32)
# -------
# 0x73752e61
# ('su.a', 'i:', 'what', 'j:', 34)
# -------
# 0x6a277477
# ("j'tw", 'i:', 'what', 'j:', 36)
# -------
# 0x387d6263
# ('8}bc', 'i:', 'what', 'j:', 38)
# -------
# 0x626b7672
# ('bkvr', 'i:', 'what', 'j:', 40)
# -------
# 0x5521
# ('U!', 'i:', 'so', 'j:', 0)
# -------
# 0x3d38
# ('=8', 'i:', 'so', 'j:', 2)
# -------
# 0x247a
# ('$z', 'i:', 'so', 'j:', 4)
# -------
# 0x6669
# ('fi', 'i:', 'so', 'j:', 6)
# -------
# 0x7572
# ('ur', 'i:', 'so', 'j:', 8)
# -------
# 0x6e3c
# ('n<', 'i:', 'so', 'j:', 10)
# -------
# 0x2022
# (' "', 'i:', 'so', 'j:', 12)
# -------
# 0x3e68
# ('>h', 'i:', 'so', 'j:', 14)
# -------
# 0x7472
# ('tr', 'i:', 'so', 'j:', 16)
# -------
# 0x6e67
# ('ng', 'i:', 'so', 'j:', 18)
# -------
# 0x7b2a
# ('{*', 'i:', 'so', 'j:', 20)
# -------
# 0x366c
# ('6l', 'i:', 'so', 'j:', 22)
# -------
# 0x7069
# ('pi', 'i:', 'so', 'j:', 24)
# -------
# 0x7570
# ('up', 'i:', 'so', 'j:', 26)
# -------
# 0x6c61
# ('la', 'i:', 'so', 'j:', 28)
# -------
# 0x7d6f
# ('}o', 'i:', 'so', 'j:', 30)
# -------
# 0x736b
# ('sk', 'i:', 'so', 'j:', 32)
# -------
# 0x7772
# ('wr', 'i:', 'so', 'j:', 34)
# -------
# 0x6e20
# ('n ', 'i:', 'so', 'j:', 36)
# -------
# 0x3c7a
# ('<z', 'i:', 'so', 'j:', 38)
# -------
# 0x666c
# ('fl', 'i:', 'so', 'j:', 40)
# -------
# 0x7078
# ('px', 'i:', 'so', 'j:', 42)
# -------
# 0x6469
# ('di', 'i:', 'so', 'j:', 44)
# -------
# 0x533e
# ('S>', 'i:', 'up', 'j:', 0)
# -------
# 0x3b27
# (";'", 'i:', 'up', 'j:', 2)
# -------
# 0x2265
# ('"e', 'i:', 'up', 'j:', 4)
# -------
# 0x6076
# ('`v', 'i:', 'up', 'j:', 6)
# -------
# 0x736d
# ('sm', 'i:', 'up', 'j:', 8)
# -------
# 0x6823
# ('h#', 'i:', 'up', 'j:', 10)
# -------
# 0x263d
# ('&=', 'i:', 'up', 'j:', 12)
# -------
# 0x3877
# ('8w', 'i:', 'up', 'j:', 14)
# -------
# 0x726d
# ('rm', 'i:', 'up', 'j:', 16)
# -------
# 0x6878
# ('hx', 'i:', 'up', 'j:', 18)
# -------
# 0x7d35
# ('}5', 'i:', 'up', 'j:', 20)
# -------
# 0x3073
# ('0s', 'i:', 'up', 'j:', 22)
# -------
# 0x7676
# ('vv', 'i:', 'up', 'j:', 24)
# -------
# 0x736f
# ('so', 'i:', 'up', 'j:', 26)
# -------
# 0x6a7e
# ('j~', 'i:', 'up', 'j:', 28)
# -------
# 0x7b70
# ('{p', 'i:', 'up', 'j:', 30)
# -------
# 0x7574
# ('ut', 'i:', 'up', 'j:', 32)
# -------
# 0x716d
# ('qm', 'i:', 'up', 'j:', 34)
# -------
# 0x683f
# ('h?', 'i:', 'up', 'j:', 36)
# -------
# 0x3a65
# (':e', 'i:', 'up', 'j:', 38)
# -------
# 0x6073
# ('`s', 'i:', 'up', 'j:', 40)
# -------
# 0x7667
# ('vg', 'i:', 'up', 'j:', 42)
# -------
# 0x6276
# ('bv', 'i:', 'up', 'j:', 44)
# -------
# 0x493b23
# ('I;#', 'i:', 'out', 'j:', 0)
# -------
# 0x212261
# ('!"a', 'i:', 'out', 'j:', 2)
# -------
# 0x386072
# ('8`r', 'i:', 'out', 'j:', 4)
# -------
# 0x7a7369
# ('zsi', 'i:', 'out', 'j:', 6)
# -------
# 0x696827
# ("ih'", 'i:', 'out', 'j:', 8)
# -------
# 0x722639
# ('r&9', 'i:', 'out', 'j:', 10)
# -------
# 0x3c3873
# ('<8s', 'i:', 'out', 'j:', 12)
# -------
# 0x227269
# ('"ri', 'i:', 'out', 'j:', 14)
# -------
# 0x68687c
# ('hh|', 'i:', 'out', 'j:', 16)
# -------
# 0x727d31
# ('r}1', 'i:', 'out', 'j:', 18)
# -------
# 0x673077
# ('g0w', 'i:', 'out', 'j:', 20)
# -------
# 0x2a7672
# ('*vr', 'i:', 'out', 'j:', 22)
# -------
# 0x6c736b
# ('lsk', 'i:', 'out', 'j:', 24)
# -------
# 0x696a7a
# ('ijz', 'i:', 'out', 'j:', 26)
# -------
# 0x707b74
# ('p{t', 'i:', 'out', 'j:', 28)
# -------
# 0x617570
# ('aup', 'i:', 'out', 'j:', 30)
# -------
# 0x6f7169
# ('oqi', 'i:', 'out', 'j:', 32)
# -------
# 0x6b683b
# ('kh;', 'i:', 'out', 'j:', 34)
# -------
# 0x723a61
# ('r:a', 'i:', 'out', 'j:', 36)
# -------
# 0x206077
# (' `w', 'i:', 'out', 'j:', 38)
# -------
# 0x7a7663
# ('zvc', 'i:', 'out', 'j:', 40)
# -------
# 0x6c6272
# ('lbr', 'i:', 'out', 'j:', 42)
# -------
# 0x4f28
# ('O(', 'i:', 'if', 'j:', 0)
# -------
# 0x2731
# ("'1", 'i:', 'if', 'j:', 2)
# -------
# 0x3e73
# ('>s', 'i:', 'if', 'j:', 4)
# -------
# 0x7c60
# ('|`', 'i:', 'if', 'j:', 6)
# -------
# 0x6f7b
# ('o{', 'i:', 'if', 'j:', 8)
# -------
# 0x7435
# ('t5', 'i:', 'if', 'j:', 10)
# -------
# 0x3a2b
# (':+', 'i:', 'if', 'j:', 12)
# -------
# 0x2461
# ('$a', 'i:', 'if', 'j:', 14)
# -------
# 0x6e7b
# ('n{', 'i:', 'if', 'j:', 16)
# -------
# 0x746e
# ('tn', 'i:', 'if', 'j:', 18)
# -------
# 0x6123
# ('a#', 'i:', 'if', 'j:', 20)
# -------
# 0x2c65
# (',e', 'i:', 'if', 'j:', 22)
# -------
# 0x6a60
# ('j`', 'i:', 'if', 'j:', 24)
# -------
# 0x6f79
# ('oy', 'i:', 'if', 'j:', 26)
# -------
# 0x7668
# ('vh', 'i:', 'if', 'j:', 28)
# -------
# 0x6766
# ('gf', 'i:', 'if', 'j:', 30)
# -------
# 0x6962
# ('ib', 'i:', 'if', 'j:', 32)
# -------
# 0x6d7b
# ('m{', 'i:', 'if', 'j:', 34)
# -------
# 0x7429
# ('t)', 'i:', 'if', 'j:', 36)
# -------
# 0x2673
# ('&s', 'i:', 'if', 'j:', 38)
# -------
# 0x7c65
# ('|e', 'i:', 'if', 'j:', 40)
# -------
# 0x6a71
# ('jq', 'i:', 'if', 'j:', 42)
# -------
# 0x7e60
# ('~`', 'i:', 'if', 'j:', 44)
# -------
# 0x472c386072
# ('G,8`r', 'i:', 'about', 'j:', 0)
# -------
# 0x2f357a7369
# ('/5zsi', 'i:', 'about', 'j:', 2)
# -------
# 0x3677696827
# ("6wih'", 'i:', 'about', 'j:', 4)
# -------
# 0x7464722639
# ('tdr&9', 'i:', 'about', 'j:', 6)
# -------
# 0x677f3c3873
# ('g\x7f<8s', 'i:', 'about', 'j:', 8)
# -------
# 0x7c31227269
# ('|1"ri', 'i:', 'about', 'j:', 10)
# -------
# 0x322f68687c
# ('2/hh|', 'i:', 'about', 'j:', 12)
# -------
# 0x2c65727d31
# (',er}1', 'i:', 'about', 'j:', 14)
# -------
# 0x667f673077
# ('f\x7fg0w', 'i:', 'about', 'j:', 16)
# -------
# 0x7c6a2a7672
# ('|j*vr', 'i:', 'about', 'j:', 18)
# -------
# 0x69276c736b
# ("i'lsk", 'i:', 'about', 'j:', 20)
# -------
# 0x2461696a7a
# ('$aijz', 'i:', 'about', 'j:', 22)
# -------
# 0x6264707b74
# ('bdp{t', 'i:', 'about', 'j:', 24)
# -------
# 0x677d617570
# ('g}aup', 'i:', 'about', 'j:', 26)
# -------
# 0x7e6c6f7169
# ('~loqi', 'i:', 'about', 'j:', 28)
# -------
# 0x6f626b683b
# ('obkh;', 'i:', 'about', 'j:', 30)
# -------
# 0x6166723a61
# ('afr:a', 'i:', 'about', 'j:', 32)
# -------
# 0x657f206077
# ('e\x7f `w', 'i:', 'about', 'j:', 34)
# -------
# 0x7c2d7a7663
# ('|-zvc', 'i:', 'about', 'j:', 36)
# -------
# 0x2e776c6272
# ('.wlbr', 'i:', 'about', 'j:', 38)
# -------
# 0x512638
# ('Q&8', 'i:', 'who', 'j:', 0)
# -------
# 0x393f7a
# ('9?z', 'i:', 'who', 'j:', 2)
# -------
# 0x207d69
# (' }i', 'i:', 'who', 'j:', 4)
# -------
# 0x626e72
# ('bnr', 'i:', 'who', 'j:', 6)
# -------
# 0x71753c
# ('qu<', 'i:', 'who', 'j:', 8)
# -------
# 0x6a3b22
# ('j;"', 'i:', 'who', 'j:', 10)
# -------
# 0x242568
# ('$%h', 'i:', 'who', 'j:', 12)
# -------
# 0x3a6f72
# (':or', 'i:', 'who', 'j:', 14)
# -------
# 0x707567
# ('pug', 'i:', 'who', 'j:', 16)
# -------
# 0x6a602a
# ('j`*', 'i:', 'who', 'j:', 18)
# -------
# 0x7f2d6c
# ('\x7f-l', 'i:', 'who', 'j:', 20)
# -------
# 0x326b69
# ('2ki', 'i:', 'who', 'j:', 22)
# -------
# 0x746e70
# ('tnp', 'i:', 'who', 'j:', 24)
# -------
# 0x717761
# ('qwa', 'i:', 'who', 'j:', 26)
# -------
# 0x68666f
# ('hfo', 'i:', 'who', 'j:', 28)
# -------
# 0x79686b
# ('yhk', 'i:', 'who', 'j:', 30)
# -------
# 0x776c72
# ('wlr', 'i:', 'who', 'j:', 32)
# -------
# 0x737520
# ('su ', 'i:', 'who', 'j:', 34)
# -------
# 0x6a277a
# ...
# -------
# 0x79656871
# ('yehq', 'i:', 'well', 'j:', 30)
# -------
# 0x77617123
# ('waq#', 'i:', 'well', 'j:', 32)
# -------
# 0x73782379
# ('sx#y', 'i:', 'well', 'j:', 34)
# -------
# 0x6a2a796f
# ('j*yo', 'i:', 'well', 'j:', 36)
# -------
# 0x38706f7b
# ('8po{', 'i:', 'well', 'j:', 38)
# -------
# 0x62667b6a
# ('bf{j', 'i:', 'well', 'j:', 40)
# -------
# 0x512f2e
# ('Q/.', 'i:', 'way', 'j:', 0)
# -------
# 0x39366c
# ('96l', 'i:', 'way', 'j:', 2)
# -------
# 0x20747f
# (' t\x7f', 'i:', 'way', 'j:', 4)
# -------
# 0x626764
# ('bgd', 'i:', 'way', 'j:', 6)
# -------
# 0x717c2a
# ('q|*', 'i:', 'way', 'j:', 8)
# -------
# 0x6a3234
# ('j24', 'i:', 'way', 'j:', 10)
# -------
# 0x242c7e
# ('$,~', 'i:', 'way', 'j:', 12)
# -------
# 0x3a6664
# (':fd', 'i:', 'way', 'j:', 14)
# -------
# 0x707c71
# ('p|q', 'i:', 'way', 'j:', 16)
# -------
# 0x6a693c
# ('ji<', 'i:', 'way', 'j:', 18)
# -------
# 0x7f247a
# ('\x7f$z', 'i:', 'way', 'j:', 20)
# -------
# 0x32627f
# ('2b\x7f', 'i:', 'way', 'j:', 22)
# -------
# 0x746766
# ('tgf', 'i:', 'way', 'j:', 24)
# -------
# 0x717e77
# ('q~w', 'i:', 'way', 'j:', 26)
# -------
# 0x686f79
# ('hoy', 'i:', 'way', 'j:', 28)
# -------
# 0x79617d
# ('ya}', 'i:', 'way', 'j:', 30)
# -------
# 0x776564
# ('wed', 'i:', 'way', 'j:', 32)
# -------
# 0x737c36
# ('s|6', 'i:', 'way', 'j:', 34)
# -------
# 0x6a2e6c
# ('j.l', 'i:', 'way', 'j:', 36)
# -------
# 0x38747a
# ('8tz', 'i:', 'way', 'j:', 38)
# -------
# 0x62626e
# ('bbn', 'i:', 'way', 'j:', 40)
# -------
# 0x74767f
# ('tv\x7f', 'i:', 'way', 'j:', 42)
# -------
# 0x4338327b
# ('C82{', 'i:', 'even', 'j:', 0)
# -------
# 0x2b217068
# ('+!ph', 'i:', 'even', 'j:', 2)
# -------
# 0x32636373
# ('2ccs', 'i:', 'even', 'j:', 4)
# -------
# 0x7070783d
# ('ppx=', 'i:', 'even', 'j:', 6)
# -------
# 0x636b3623
# ('ck6#', 'i:', 'even', 'j:', 8)
# -------
# 0x78252869
# ('x%(i', 'i:', 'even', 'j:', 10)
# -------
# 0x363b6273
# ('6;bs', 'i:', 'even', 'j:', 12)
# -------
# 0x28717866
# ('(qxf', 'i:', 'even', 'j:', 14)
# -------
# 0x626b6d2b
# ('bkm+', 'i:', 'even', 'j:', 16)
# -------
# 0x787e206d
# ('x~ m', 'i:', 'even', 'j:', 18)
# -------
# 0x6d336668
# ('m3fh', 'i:', 'even', 'j:', 20)
# -------
# 0x20756371
# (' ucq', 'i:', 'even', 'j:', 22)
# -------
# 0x66707a60
# ('fpz`', 'i:', 'even', 'j:', 24)
# -------
# 0x63696b6e
# ('cikn', 'i:', 'even', 'j:', 26)
# -------
# 0x7a78656a
# ('zxej', 'i:', 'even', 'j:', 28)
# -------
# 0x6b766173
# ('kvas', 'i:', 'even', 'j:', 30)
# -------
# 0x65727821
# ('erx!', 'i:', 'even', 'j:', 32)
# -------
# 0x616b2a7b
# ('ak*{', 'i:', 'even', 'j:', 34)
# -------
# 0x7839706d
# ('x9pm', 'i:', 'even', 'j:', 36)
# -------
# 0x2a636679
# ('*cfy', 'i:', 'even', 'j:', 38)
# -------
# 0x70757268
# ('purh', 'i:', 'even', 'j:', 40)
# -------
# 0x482b20
# ('H+ ', 'i:', 'new', 'j:', 0)
# -------
# 0x203262
# (' 2b', 'i:', 'new', 'j:', 2)
# -------
# 0x397071
# ('9pq', 'i:', 'new', 'j:', 4)
# -------
# 0x7b636a
# ('{cj', 'i:', 'new', 'j:', 6)
# -------
# 0x687824
# ('hx$', 'i:', 'new', 'j:', 8)
# -------
# 0x73363a
# ('s6:', 'i:', 'new', 'j:', 10)
# -------
# 0x3d2870
# ('=(p', 'i:', 'new', 'j:', 12)
# -------
# 0x23626a
# ('#bj', 'i:', 'new', 'j:', 14)
# -------
# 0x69787f
# ('ix\x7f', 'i:', 'new', 'j:', 16)
# -------
# 0x736d32
# ('sm2', 'i:', 'new', 'j:', 18)
# -------
# 0x662074
# ('f t', 'i:', 'new', 'j:', 20)
# -------
# 0x2b6671
# ('+fq', 'i:', 'new', 'j:', 22)
# -------
# 0x6d6368
# ('mch', 'i:', 'new', 'j:', 24)
# -------
# 0x687a79
# ('hzy', 'i:', 'new', 'j:', 26)
# -------
# 0x716b77
# ('qkw', 'i:', 'new', 'j:', 28)
# -------
# 0x606573
# ('`es', 'i:', 'new', 'j:', 30)
# -------
# 0x6e616a
# ('naj', 'i:', 'new', 'j:', 32)
# -------
# 0x6a7838
# ('jx8', 'i:', 'new', 'j:', 34)
# -------
# 0x732a62
# ('s*b', 'i:', 'new', 'j:', 36)
# -------
# 0x217074
# ('!pt', 'i:', 'new', 'j:', 38)
# -------
# 0x7b6660
# ('{f`', 'i:', 'new', 'j:', 40)
# -------
# 0x6d7271
# ('mrq', 'i:', 'new', 'j:', 42)
# -------
# 0x512f3961
# ('Q/9a', 'i:', 'want', 'j:', 0)
# -------
# 0x39367b72
# ('96{r', 'i:', 'want', 'j:', 2)
# -------
# 0x20746869
# (' thi', 'i:', 'want', 'j:', 4)
# -------
# 0x62677327
# ("bgs'", 'i:', 'want', 'j:', 6)
# -------
# 0x717c3d39
# ('q|=9', 'i:', 'want', 'j:', 8)
# -------
# 0x6a322373
# ('j2#s', 'i:', 'want', 'j:', 10)
# -------
# 0x242c6969
# ('$,ii', 'i:', 'want', 'j:', 12)
# -------
# 0x3a66737c
# (':fs|', 'i:', 'want', 'j:', 14)
# -------
# 0x707c6631
# ('p|f1', 'i:', 'want', 'j:', 16)
# -------
# 0x6a692b77
# ('ji+w', 'i:', 'want', 'j:', 18)
# -------
# 0x7f246d72
# ('\x7f$mr', 'i:', 'want', 'j:', 20)
# -------
# 0x3262686b
# ('2bhk', 'i:', 'want', 'j:', 22)
# -------
# 0x7467717a
# ('tgqz', 'i:', 'want', 'j:', 24)
# -------
# 0x717e6074
# ('q~`t', 'i:', 'want', 'j:', 26)
# -------
# 0x686f6e70
# ('honp', 'i:', 'want', 'j:', 28)
# -------
# 0x79616a69
# ('yaji', 'i:', 'want', 'j:', 30)
# -------
# 0x7765733b
# ('wes;', 'i:', 'want', 'j:', 32)
# -------
# 0x737c2161
# ('s|!a', 'i:', 'want', 'j:', 34)
# -------
# 0x6a2e7b77
# ('j.{w', 'i:', 'want', 'j:', 36)
# -------
# 0x38746d63
# ('8tmc', 'i:', 'want', 'j:', 38)
# -------
# 0x62627972
# ('bbyr', 'i:', 'want', 'j:', 40)
# -------
# 0x442b3474736e
# ('D+4tsn', 'i:', 'becaus', 'j:', 0)
# -------
# 0x2c3276676820
# (',2vgh ', 'i:', 'becaus', 'j:', 2)
# -------
# 0x3570657c263e
# ('5pe|&>', 'i:', 'becaus', 'j:', 4)
# -------
# 0x77637e323874
# ('wc~28t', 'i:', 'becaus', 'j:', 6)
# -------
# 0x6478302c726e
# ('dx0,rn', 'i:', 'becaus', 'j:', 8)
# -------
# 0x7f362e66687b
# ('\x7f6.fh{', 'i:', 'becaus', 'j:', 10)
# -------
# 0x3128647c7d36
# ('1(d|}6', 'i:', 'becaus', 'j:', 12)
# -------
# 0x2f627e693070
# ('/b~i0p', 'i:', 'becaus', 'j:', 14)
# -------
# 0x65786b247675
# ('exk$vu', 'i:', 'becaus', 'j:', 16)
# -------
# 0x7f6d2662736c
# ('\x7fm&bsl', 'i:', 'becaus', 'j:', 18)
# -------
# 0x6a2060676a7d
# ('j `gj}', 'i:', 'becaus', 'j:', 20)
# -------
# 0x2766657e7b73
# ("'fe~{s", 'i:', 'becaus', 'j:', 22)
# -------
# 0x61637c6f7577
# ('ac|ouw', 'i:', 'becaus', 'j:', 24)
# -------
# 0x647a6d61716e
# ('dzmaqn', 'i:', 'becaus', 'j:', 26)
# -------
# 0x7d6b6365683c
# ('}kceh<', 'i:', 'becaus', 'j:', 28)
# -------
# 0x6c65677c3a66
# ('leg|:f', 'i:', 'becaus', 'j:', 30)
# -------
# 0x62617e2e6070
# ('ba~.`p', 'i:', 'becaus', 'j:', 32)
# -------
# 0x66782c747664
# ('fx,tvd', 'i:', 'becaus', 'j:', 34)
# -------
# 0x7f2a76626275
# ('\x7f*vbbu', 'i:', 'becaus', 'j:', 36)
# -------
# 0x47202e
# ('G .', 'i:', 'any', 'j:', 0)
# -------
# 0x2f396c
# ('/9l', 'i:', 'any', 'j:', 2)
# -------
# 0x367b7f
# ('6{\x7f', 'i:', 'any', 'j:', 4)
# -------
# 0x746864
# ('thd', 'i:', 'any', 'j:', 6)
# -------
# 0x67732a
# ('gs*', 'i:', 'any', 'j:', 8)
# -------
# 0x7c3d34
# ('|=4', 'i:', 'any', 'j:', 10)
# -------
# 0x32237e
# ('2#~', 'i:', 'any', 'j:', 12)
# -------
# 0x2c6964
# (',id', 'i:', 'any', 'j:', 14)
# -------
# 0x667371
# ('fsq', 'i:', 'any', 'j:', 16)
# -------
# 0x7c663c
# ('|f<', 'i:', 'any', 'j:', 18)
# -------
# 0x692b7a
# ('i+z', 'i:', 'any', 'j:', 20)
# -------
# 0x246d7f
# ('$m\x7f', 'i:', 'any', 'j:', 22)
# -------
# 0x626866
# ('bhf', 'i:', 'any', 'j:', 24)
# -------
# 0x677177
# ('gqw', 'i:', 'any', 'j:', 26)
# -------
# 0x7e6079
# ('~`y', 'i:', 'any', 'j:', 28)
# -------
# 0x6f6e7d
# ('on}', 'i:', 'any', 'j:', 30)
# -------
# 0x616a64
# ('ajd', 'i:', 'any', 'j:', 32)
# -------
# 0x657336
# ('es6', 'i:', 'any', 'j:', 34)
# -------
# 0x7c216c
# ('|!l', 'i:', 'any', 'j:', 36)
# -------
# 0x2e7b7a
# ('.{z', 'i:', 'any', 'j:', 38)
# -------
# 0x746d6e
# ('tmn', 'i:', 'any', 'j:', 40)
# -------
# 0x62797f
# ('by\x7f', 'i:', 'any', 'j:', 42)
# -------
# 0x5226326663
# ('R&2fc', 'i:', 'these', 'j:', 0)
# -------
# 0x3a3f707578
# (':?pux', 'i:', 'these', 'j:', 2)
# -------
# 0x237d636e36
# ('#}cn6', 'i:', 'these', 'j:', 4)
# -------
# 0x616e782028
# ('anx (', 'i:', 'these', 'j:', 6)
# -------
# 0x7275363e62
# ('ru6>b', 'i:', 'these', 'j:', 8)
# -------
# 0x693b287478
# ('i;(tx', 'i:', 'these', 'j:', 10)
# -------
# 0x2725626e6d
# ("'%bnm", 'i:', 'these', 'j:', 12)
# -------
# 0x396f787b20
# ('9ox{ ', 'i:', 'these', 'j:', 14)
# -------
# 0x73756d3666
# ('sum6f', 'i:', 'these', 'j:', 16)
# -------
# 0x6960207063
# ('i` pc', 'i:', 'these', 'j:', 18)
# -------
# 0x7c2d66757a
# ('|-fuz', 'i:', 'these', 'j:', 20)
# -------
# 0x316b636c6b
# ('1kclk', 'i:', 'these', 'j:', 22)
# -------
# 0x776e7a7d65
# ('wnz}e', 'i:', 'these', 'j:', 24)
# -------
# 0x72776b7361
# ('rwksa', 'i:', 'these', 'j:', 26)
# -------
# 0x6b66657778
# ('kfewx', 'i:', 'these', 'j:', 28)
# -------
# 0x7a68616e2a
# ('zhan*', 'i:', 'these', 'j:', 30)
# -------
# 0x746c783c70
# ('tlx<p', 'i:', 'these', 'j:', 32)
# -------
# 0x70752a6666
# ('pu*ff', 'i:', 'these', 'j:', 34)
# -------
# 0x6927707072
# ("i'ppr", 'i:', 'these', 'j:', 36)
# -------
# 0x3b7d666463
# (';}fdc', 'i:', 'these', 'j:', 38)
# -------
# 0x41272170
# ("A'!p", 'i:', 'give', 'j:', 0)
# -------
# 0x293e6363
# (')>cc', 'i:', 'give', 'j:', 2)
# -------
# 0x307c7078
# ('0|px', 'i:', 'give', 'j:', 4)
# -------
# 0x726f6b36
# ('rok6', 'i:', 'give', 'j:', 6)
# -------
# 0x61742528
# ('at%(', 'i:', 'give', 'j:', 8)
# -------
# 0x7a3a3b62
# ('z:;b', 'i:', 'give', 'j:', 10)
# -------
# 0x34247178
# ('4$qx', 'i:', 'give', 'j:', 12)
# -------
# 0x2a6e6b6d
# ('*nkm', 'i:', 'give', 'j:', 14)
# -------
# 0x60747e20
# ('`t~ ', 'i:', 'give', 'j:', 16)
# -------
# 0x7a613366
# ('za3f', 'i:', 'give', 'j:', 18)
# -------
# 0x6f2c7563
# ('o,uc', 'i:', 'give', 'j:', 20)
# -------
# 0x226a707a
# ('"jpz', 'i:', 'give', 'j:', 22)
# -------
# 0x646f696b
# ('doik', 'i:', 'give', 'j:', 24)
# -------
# 0x61767865
# ('avxe', 'i:', 'give', 'j:', 26)
# -------
# 0x78677661
# ('xgva', 'i:', 'give', 'j:', 28)
# -------
# 0x69697278
# ('iirx', 'i:', 'give', 'j:', 30)
# -------
# 0x676d6b2a
# ('gmk*', 'i:', 'give', 'j:', 32)
# -------
# 0x63743970
# ('ct9p', 'i:', 'give', 'j:', 34)
# -------
# 0x7a266366
# ('z&cf', 'i:', 'give', 'j:', 36)
# -------
# 0x287c7572
# ('(|ur', 'i:', 'give', 'j:', 38)
# -------
# 0x726a6163
# ('rjac', 'i:', 'give', 'j:', 40)
# -------
# 0x422f2e
# ('B/.', 'i:', 'day', 'j:', 0)
# -------
# 0x2a366c
# ('*6l', 'i:', 'day', 'j:', 2)
# -------
# 0x33747f
# ('3t\x7f', 'i:', 'day', 'j:', 4)
# -------
# 0x716764
# ('qgd', 'i:', 'day', 'j:', 6)
# -------
# 0x627c2a
# ('b|*', 'i:', 'day', 'j:', 8)
# -------
# 0x793234
# ('y24', 'i:', 'day', 'j:', 10)
# -------
# 0x372c7e
# ('7,~', 'i:', 'day', 'j:', 12)
# -------
# 0x296664
# (')fd', 'i:', 'day', 'j:', 14)
# -------
# 0x637c71
# ('c|q', 'i:', 'day', 'j:', 16)
# -------
# 0x79693c
# ('yi<', 'i:', 'day', 'j:', 18)
# -------
# 0x6c247a
# ('l$z', 'i:', 'day', 'j:', 20)
# -------
# 0x21627f
# ('!b\x7f', 'i:', 'day', 'j:', 22)
# -------
# 0x676766
# ('ggf', 'i:', 'day', 'j:', 24)
# -------
# 0x627e77
# ('b~w', 'i:', 'day', 'j:', 26)
# -------
# 0x7b6f79
# ('{oy', 'i:', 'day', 'j:', 28)
# -------
# 0x6a617d
# ('ja}', 'i:', 'day', 'j:', 30)
# -------
# 0x646564
# ('ded', 'i:', 'day', 'j:', 32)
# -------
# 0x607c36
# ('`|6', 'i:', 'day', 'j:', 34)
# -------
# 0x792e6c
# ('y.l', 'i:', 'day', 'j:', 36)
# -------
# 0x2b747a
# ('+tz', 'i:', 'day', 'j:', 38)
# -------
# 0x71626e
# ('qbn', 'i:', 'day', 'j:', 40)
# -------
# 0x67767f
# ('gv\x7f', 'i:', 'day', 'j:', 42)
# -------
# 0x4b212461
# ('K!$a', 'i:', 'most', 'j:', 0)
# -------
# 0x23386672
# ('#8fr', 'i:', 'most', 'j:', 2)
# -------
# 0x3a7a7569
# (':zui', 'i:', 'most', 'j:', 4)
# -------
# 0x78696e27
# ("xin'", 'i:', 'most', 'j:', 6)
# -------
# 0x6b722039
# ('kr 9', 'i:', 'most', 'j:', 8)
# -------
# 0x703c3e73
# ('p<>s', 'i:', 'most', 'j:', 10)
# -------
# 0x3e227469
# ('>"ti', 'i:', 'most', 'j:', 12)
# -------
# 0x20686e7c
# (' hn|', 'i:', 'most', 'j:', 14)
# -------
# 0x6a727b31
# ('jr{1', 'i:', 'most', 'j:', 16)
# -------
# 0x70673677
# ('pg6w', 'i:', 'most', 'j:', 18)
# -------
# 0x652a7072
# ('e*pr', 'i:', 'most', 'j:', 20)
# -------
# 0x286c756b
# ('(luk', 'i:', 'most', 'j:', 22)
# -------
# 0x6e696c7a
# ('nilz', 'i:', 'most', 'j:', 24)
# -------
# 0x6b707d74
# ('kp}t', 'i:', 'most', 'j:', 26)
# -------
# 0x72617370
# ('rasp', 'i:', 'most', 'j:', 28)
# -------
# 0x636f7769
# ('cowi', 'i:', 'most', 'j:', 30)
# -------
# 0x6d6b6e3b
# ('mkn;', 'i:', 'most', 'j:', 32)
# -------
# 0x69723c61
# ('ir<a', 'i:', 'most', 'j:', 34)
# -------
# 0x70206677
# ('p fw', 'i:', 'most', 'j:', 36)
# -------
# 0x227a7063
# ('"zpc', 'i:', 'most', 'j:', 38)
# -------
# 0x786c6472
# ('xldr', 'i:', 'most', 'j:', 40)
# -------
# 0x533d77
# ('S=w', 'i:', 'us ', 'j:', 0)
# -------
# 0x3b2435
# (';$5', 'i:', 'us ', 'j:', 2)
# -------
# 0x226626
# ('"f&', 'i:', 'us ', 'j:', 4)
# -------
# 0x60753d
# ('`u=', 'i:', 'us ', 'j:', 6)
# -------
# 0x736e73
# ('sns', 'i:', 'us ', 'j:', 8)
# -------
# 0x68206d
# ('h m', 'i:', 'us ', 'j:', 10)
# -------
# 0x263e27
# ("&>'", 'i:', 'us ', 'j:', 12)
# -------
# 0x38743d
# ('8t=', 'i:', 'us ', 'j:', 14)
# -------
# 0x726e28
# ('rn(', 'i:', 'us ', 'j:', 16)
# -------
# 0x687b65
# ('h{e', 'i:', 'us ', 'j:', 18)
# -------
# 0x7d3623
# ('}6#', 'i:', 'us ', 'j:', 20)
# -------
# 0x307026
# ('0p&', 'i:', 'us ', 'j:', 22)
# -------
# 0x76753f
# ('vu?', 'i:', 'us ', 'j:', 24)
# -------
# 0x736c2e
# ('sl.', 'i:', 'us ', 'j:', 26)
# -------
# 0x6a7d20
# ('j} ', 'i:', 'us ', 'j:', 28)
# -------
# 0x7b7324
# ('{s$', 'i:', 'us ', 'j:', 30)
# -------
# 0x75773d
# ('uw=', 'i:', 'us ', 'j:', 32)
# -------
# 0x716e6f
# ('qno', 'i:', 'us ', 'j:', 34)
# -------
# 0x683c35
# ('h<5', 'i:', 'us ', 'j:', 36)
# -------
# 0x3a6623
# (':f#', 'i:', 'us ', 'j:', 38)
# -------
# 0x607037
# ('`p7', 'i:', 'us ', 'j:', 40)
# -------
# 0x766426
# ('vd&', 'i:', 'us ', 'j:', 42)
# -------
# ['anx', 'sum', 'wnz', 'rwk', 'kfe', 'zha', 'tlx', 'akr', 'wc', 'dx', 'ex', 'ac', 'dz', 'le', 'ba', 'fx', 'wf', 'ar', 'uc', 'ai', 'rr', 'sr', 'ig', 'wi', 'rp', 'ka', 'zo', 'tk', 'pr', 'al', 'wx', 'ci', 'rn', 'iy', 'ph', 'af', 'ob', 'ze', 'lq', 'thy', 'fsl', 'gqj', 'ajy', 'tms', 'byb', 'G', 't', 'g', 'f', 'i', 'b', 'g', 'o', 'a', 'e', 't', 'b', 'v', 'g', 'os', 'ns', 'tf', 'jh', 'oq', 'gn', 'ij', 'ms', 'jy', 'rwot', 'kfap', 'zhei', 'akvr', 'kgik', 'wova', 'farx', 'o', 'O', 'T', 'N', 'T', 'A', 'J', 'O', 'V', 'G', 'I', 'M', 'T', 'J', 'O', 'oi', 'ni', 'jr', 'ok', 'vz', 'gt', 'ip', 'mi', 'jc', 'sio', 'arz', 'eim', 'yar', 'hov', 'fko', 'sle', 'ext', 'mik', 'hpz', 'qat', 'nki', 'mxr', 'zh', 'is', 'hs', 'rf', 'lh', 'iq', 'an', 'oj', 'ks', 'zm', 'ly', 'xh', 'tokf', 'qvzh', 'hgtl', 'yipu', 'bjcn', 'nx', 'ox', 'um', 'kc', 'nz', 'wk', 'fe', 'ha', 'lx', 'kr', 'tu', 'gn', 'fn', 'bu', 'gl', 'os', 'aw', 'en', 'tp', 'bd', 'vu', 'lih', 'zij', 'fau', 'woq', 'ykh', 'llb', 'zxs', 'qi', 'br', 'cr', 'yg', 'gi', 'bp', 'jo', 'dk', 'ql', 'gx', 'si', 'tr', 'gi', 'fi', 'br', 'gk', 'ot', 'ap', 'ei', 'tw', 'bc', 'vr', 'rwgs', 'kfiw', 'zhmn', 'wsi', 'ask', 'djz', 'lup', 'bqi', 'wvc', 'abr', 'kol', 'wgs', 'fiw', 'hmn', 'dd', 'ed', 'df', 'ly', 'fd', 'wz', 'an', 'etpc', 'hrkp', 'sqxk', 'wnzw', 'rwky', 'zhad', 'bc', 'qx', 'px', 'jm', 'tc', 'qz', 'hk', 'ye', 'wa', 'sx', 'bf', 'tr', 'fgd', 'pgf', 'loy', 'sed', 'fbn', 'oxz', 'kcm', 'wkr', 'fev', 'hao', 'krt', 'fnx', 'tum', 'pnz', 'uwk', 'lfe', 'slx', 'fkr', 'zt', 'io', 'ho', 'rz', 'lt', 'im', 'ar', 'ov', 'ko', 'zq', 'le', 'xt', 'tosb', 'qvbl', 'hglh', 'yihq', 'kd', 'jd', 'pq', 'kf', 'rw', 'cy', 'id', 'xz', 'nn', 'zhx', 'hsm', 'lhz', 'iqk', 'ana', 'ojx', 'zmr', 'lyc', 'tjq', 'fqd', 'bjs', 'gsb', 'olh', 'ahq', 'tijbd', 'hauhy', 'rwkra', 'kfevx', 'wnzgr', 'rwkiv', 'kfemo', 'qwot', 'hfap', 'yhei', 'bkvr', 'fi', 'ur', 'tr', 'ng', 'pi', 'up', 'la', 'sk', 'wr', 'fl', 'px', 'di', 'sm', 'rm', 'hx', 'vv', 'so', 'ut', 'qm', 'vg', 'bv', 'zsi', 'lsk', 'ijz', 'aup', 'oqi', 'zvc', 'lbr', 'tn', 'oy', 'vh', 'gf', 'ib', 'jq', 'bnr', 'pug', 'tnp', 'qwa', 'hfo', 'yhk', 'wlr', 'bkx', 'rci', 'dck', 'azz', 'xkt', 'iep', 'gai', 'rfc', 'drr', 'tnvmh', 'qwgcl', 'hfigu', 'ri', 'ar', 'zg', 'di', 'ap', 'xa', 'io', 'gk', 'cr', 'rl', 'dx', 'pi', 'qwkn', 'hfej', 'yhas', 'bkrh', 'xc', 'kx', 'jx', 'pm', 'nc', 'kz', 'rk', 'ce', 'ma', 'ix', 'xf', 'nr', 'zc', 'ngtk', 'roka', 'caox', 'vgs', 'maj', 'ces', 'vby', 'ootk', 'jvee', 'sgka', 'biox', 'ework', 'oajzc', 'hr', 'ir', 'sg', 'mi', 'hp', 'qa', 'nk', 'jr', 'mx', 'yi', 'islz', 'duwi', 'ote', 'kor', 'nvc', 'wgm', 'fii', 'hmp', 'hhpy', 'mqaw', 'enkj', 'wgtk', 'koka', 'zaox', 'jhka', 'oqzo', 'gnpr', 'fkav', 'weeo', 'lfvt', 'fauv', 'woqo', 'llbt', 'dipj', 'apad', 'ioky', 'rlxb', 'pirk', 'upce', 'lama', 'flzc', 'wnzc', 'rwkm', 'kfei', 'zhap', 'akrk', 'fcx', 'txm', 'pcz', 'uzk', 'lke', 'sax', 'ffr', 'prc', 'lrwkr', 'ikfev', 'pzhao', 'rwon', 'kfaj', 'zhes', 'akvh', 'rwkn', 'kfej', 'zhas', 'akrh', 'mih', 'hpy', 'qaw', 'nkj', 'mxq', 'oipe', 'jpak', 'saoo', 'bokv', 'ylxm', 'lhsw', 'iqby', 'anhd', 'epce', 'moix', 'vlzc', 'jrl', 'vzs', 'gtw', 'ipn', 'jcu', 'iikr', 'pxev', 'avao', 'zurt', 'rwgno', 'kfijv', 'bjla', 'olwr', 'todi', 'lagv', 'wbtm', 'gyzev', 'rnm', 'vuz', 'slk', 'uwx', 'vdc', 'aqr', 'sjg', 'wqp', 'rha', 'kyo', 'zwk', 'tsr', 'atx', 'kih', 'npy', 'waw', 'fos', 'hkj', 'kxq', 'zso', 'hhz', 'lsm', 'auv', 'oqo', 'zve', 'lbt', 'ygrwi', 'tcsb', 'qzbl', 'hklh', 'yehq', 'bgd', 'tgf', 'hoy', 'wed', 'bbn', 'cikn', 'zxej', 'kvas', 'purh', 'mch', 'hzy', 'qkw', 'naj', 'mrq', 'tgqz', 'honp', 'yaji', 'bbyr', 'dzmaqn', 'thd', 'fsq', 'bhf', 'gqw', 'ajd', 'tmn', 'rwksa', 'kfewx', 'doik', 'avxe', 'xgva', 'iirx', 'rjac', 'qgd', 'ggf', 'ded', 'qbn', 'nilz', 'rasp', 'cowi', 'xldr', 'sns', 'qno']

# %%
hex_2_string('51b1ea3410')

# %%
word = "the"
word_hex = string_2_hex(word)
print((word_hex))
# Out:
# 746865

# %%
hex_str = "0xAD4"

print hex(new_int)
# Out:
# 0xcd4

# %%
0x123
# Out:
# 291

# %%
0x70757a7a6c65
# Out:
# 123649868328037

# %%
int("70757a7a6c65", 16)
# Out:
# 123649868328037

# %%
0x746865
# Out:
# 7628901

# %%
hex(0x3c0d09 ^ 0x746865)
# Out:
# '0x48656c'

# %%
(hex(hex_2_int('3c0d094c1f523808000d09'[0:len("746865")-1]) ^ hex_2_int('746865')))
# Out:
# '0x77a8b5'

# %%
'3c0d094c1f523808000d09'[j:len("746865")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-209-5e83dbc8413a> in <module>()
# ----> 1 '3c0d094c1f523808000d09'[j:len("746865")]
#
# NameError: name 'j' is not defined

# %%
 c1 = hex_2_int("57fbbaa76f6513d4b0685e651dc75dfed0a2dca24b9e42bf")
 c2 = hex_2_int("71b5edb269784099b77556201ec142f0d0a6c1ed5e9d55b9")
 c1XorCw = hex(c1^c2)[2:]

# %%
print(c1XorCw)
# Out:
# 264e5715061d534d071d084503061f0e00041d4f15031706L

# %%
string_2_hex("sometime ")
# Out:
# '736f6d6574696d6520'

# %%
hex(0x57fbbaa76f6513d4b0685e651dc75dfed0a2dca24b9e42bf ^ 0x71b5edb269784099b77556201ec142f0d0a6c1ed5e9d55b9)
# Out:
# '0x264e5715061d534d071d084503061f0e00041d4f15031706L'

# %%
# Out:
# 48

# %%
# Out:
# '00'

# %%
hex_2_string("2")
# Out:
# ''

# %%
("264e5715061d534d071d084503061f0e00041d4f15031706")[16:]   #etime
# Out:
# '071d084503061f0e00041d4f15031706'

# %%
hex_2_string((hex(hex_2_int(string_2_hex("I want more time to work")) ^ (hex_2_int("264e5715061d534d071d084503061f0e00041d4f15031706")))[:-1])[2:])
# Out:
# 'on this homework problem'

# %%
hex_2_string((hex(hex_2_int(string_2_hex("on this homework problem")) ^ (hex_2_int("264e5715061d534d071d084503061f0e00041d4f15031706")))[:-1])[2:])
# Out:
# 'I want more time to work'
